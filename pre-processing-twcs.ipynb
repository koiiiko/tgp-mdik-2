# %% [markdown]
# ### Connect spark and deltalake

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("DeltaLake with Hive Integration") \
    .master("local[*]") \
    .config("spark.jars.packages", 
            "org.apache.spark:spark-sql-kafka-0-10_2.13:4.0.0,io.delta:delta-spark_2.13:4.0.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.sql.warehouse.dir", "hive") \
    .config("spark.python.worker.timeout", "1200") \
    .config("spark.network.timeout", "1200s") \
    .config("spark.executor.heartbeatInterval", "60s") \
    .config("spark.python.worker.reuse", "true") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .enableHiveSupport() \
    .getOrCreate()

df_twcs = spark.read.format("delta").load("hdfs://localhost:9000/delta_twcs")
print(df_twcs)
# Out:
# DataFrame[message: string, timestamp_kafka: timestamp]

# %% [markdown]
# ### Preprocessing tweets data

# %%
import pandas as pd 
import numpy as np 
import json

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import StopWordsRemover

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# Map delta format data to dataframe

# %%
df_parsed = df_twcs.select(
    col("timestamp_kafka"),
    from_json(
        col("message"),
        "tweet_id string, author_id string, inbound string, created_at string, text string, response_tweet_id string, in_response_to_tweet_id string"
    ).alias("data"))


df_column = df_parsed.select(
    col("timestamp_kafka"),
    col("data.tweet_id").alias("tweet_id"),
    col("data.author_id").alias("author_id"),
    (col("data.inbound") == "True").alias("inbound"),
    col("data.created_at").alias("created_at"),
    col("data.text").alias("text"),
    col("data.response_tweet_id").alias("response_tweet_id"),
    col("data.in_response_to_tweet_id").alias("in_response_to_tweet_id")
).filter(col("tweet_id").isNotNull())

# %%
df_parsed.show(10, truncate=False)
df_column.show(10, truncate=False)
df_parsed.printSchema()
# Out:
# +-----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |data                                                                                                                                                                                                             |
# +-----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-27 12:57:26.818|{1317615, TMobileHelp, False, Fri Oct 27 08:13:27 +0000 2017, @427759 What's going on, Hadas? *NaeJ, , 1317616}                                                                                                  |
# |2025-06-27 12:57:26.818|{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                       |
# |2025-06-27 12:57:26.818|{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                       |
# |2025-06-27 12:57:26.818|{1317618, TMobileHelp, False, Fri Oct 27 08:13:25 +0000 2017, @427761 https://t.co/xKtJVNqc2V *RileyRed, , 1317619}                                                                                              |
# |2025-06-27 12:57:26.818|{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                       |
# |2025-06-27 12:57:26.818|{1317621, 427762, True, Fri Oct 27 08:08:53 +0000 2017, @115911 Hi there. I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email. Is that normal?, 1317619,1317622, }|
# |2025-06-27 12:57:26.818|{1317620, TMobileHelp, False, Fri Oct 27 08:13:21 +0000 2017, @427761 If you can confirm your account for me I can jump right in! *RileyRed, , 1317619}                                                          |
# |2025-06-27 12:57:26.818|{1317623, TMobileHelp, False, Fri Oct 27 08:13:19 +0000 2017, @426997 I see your DM and will be responding shortly. Thanks for hanging in there with us. *JeromyBingham, , 1317624}                              |
# |2025-06-27 12:57:26.818|{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                       |
# |2025-06-27 12:57:26.818|{1317625, TMobileHelp, False, Fri Oct 27 08:02:48 +0000 2017, @426997 We want to make sure you have all the information about your order. Let's take a look, send us a DM. *JeromyBingham, 1317624, 1317626}     |
# +-----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+
# |timestamp_kafka        |tweet_id|author_id  |inbound|created_at                    |text                                                                                                                                 |response_tweet_id|in_response_to_tweet_id|
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+
# |2025-06-27 12:57:26.818|1317615 |TMobileHelp|false  |Fri Oct 27 08:13:27 +0000 2017|@427759 What's going on, Hadas? *NaeJ                                                                                                |                 |1317616                |
# |2025-06-27 12:57:26.818|1317618 |TMobileHelp|false  |Fri Oct 27 08:13:25 +0000 2017|@427761 https://t.co/xKtJVNqc2V *RileyRed                                                                                            |                 |1317619                |
# |2025-06-27 12:57:26.818|1317621 |427762     |true   |Fri Oct 27 08:08:53 +0000 2017|@115911 Hi there. I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email. Is that normal?|1317619,1317622  |                       |
# |2025-06-27 12:57:26.818|1317620 |TMobileHelp|false  |Fri Oct 27 08:13:21 +0000 2017|@427761 If you can confirm your account for me I can jump right in! *RileyRed                                                        |                 |1317619                |
# |2025-06-27 12:57:26.818|1317623 |TMobileHelp|false  |Fri Oct 27 08:13:19 +0000 2017|@426997 I see your DM and will be responding shortly. Thanks for hanging in there with us. *JeromyBingham                            |                 |1317624                |
# |2025-06-27 12:57:26.818|1317625 |TMobileHelp|false  |Fri Oct 27 08:02:48 +0000 2017|@426997 We want to make sure you have all the information about your order. Let's take a look, send us a DM. *JeromyBingham          |1317624          |1317626                |
# |2025-06-27 12:57:26.819|1317628 |426998     |true   |Fri Oct 27 07:53:52 +0000 2017|@426997 nah going to store I need it on the 3rd                                                                                      |1317627          |1317629                |
# |2025-06-27 12:57:26.819|1317629 |426997     |true   |Fri Oct 27 07:52:10 +0000 2017|@426998 Why bruh, keep trying                                                                                                        |1317628          |1317630                |
# |2025-06-27 12:57:26.819|1317631 |426997     |true   |Fri Oct 27 07:47:19 +0000 2017|@426998 Got it bro, I dunno if I should go back to sleep or just wait and go to work early lol                                       |1317630          |1317632                |
# |2025-06-27 12:57:26.819|1317632 |426998     |true   |Fri Oct 27 07:35:06 +0000 2017|@426997 I might have to go to the store early to get one                                                                             |1317631          |1317633                |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+
# only showing top 10 rows
# root
#  |-- timestamp_kafka: timestamp (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- tweet_id: string (nullable = true)
#  |    |-- author_id: string (nullable = true)
#  |    |-- inbound: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- response_tweet_id: string (nullable = true)
#  |    |-- in_response_to_tweet_id: string (nullable = true)

# %% [markdown]
# Convert to lowercase

# %%
df_twcs_clean = df_column.withColumn("text_clean", lower(col("text")))
df_twcs_clean.show(10, truncate=False)
# Out:
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |tweet_id|author_id  |inbound|created_at                    |text                                                                                                                                 |response_tweet_id|in_response_to_tweet_id|text_clean                                                                                                                           |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-27 12:57:26.818|1317615 |TMobileHelp|false  |Fri Oct 27 08:13:27 +0000 2017|@427759 What's going on, Hadas? *NaeJ                                                                                                |                 |1317616                |@427759 what's going on, hadas? *naej                                                                                                |
# |2025-06-27 12:57:26.818|1317618 |TMobileHelp|false  |Fri Oct 27 08:13:25 +0000 2017|@427761 https://t.co/xKtJVNqc2V *RileyRed                                                                                            |                 |1317619                |@427761 https://t.co/xktjvnqc2v *rileyred                                                                                            |
# |2025-06-27 12:57:26.818|1317621 |427762     |true   |Fri Oct 27 08:08:53 +0000 2017|@115911 Hi there. I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email. Is that normal?|1317619,1317622  |                       |@115911 hi there. i spoke with a rep to place an iphone x order but have not received any sort of confirmation email. is that normal?|
# |2025-06-27 12:57:26.818|1317620 |TMobileHelp|false  |Fri Oct 27 08:13:21 +0000 2017|@427761 If you can confirm your account for me I can jump right in! *RileyRed                                                        |                 |1317619                |@427761 if you can confirm your account for me i can jump right in! *rileyred                                                        |
# |2025-06-27 12:57:26.818|1317623 |TMobileHelp|false  |Fri Oct 27 08:13:19 +0000 2017|@426997 I see your DM and will be responding shortly. Thanks for hanging in there with us. *JeromyBingham                            |                 |1317624                |@426997 i see your dm and will be responding shortly. thanks for hanging in there with us. *jeromybingham                            |
# |2025-06-27 12:57:26.818|1317625 |TMobileHelp|false  |Fri Oct 27 08:02:48 +0000 2017|@426997 We want to make sure you have all the information about your order. Let's take a look, send us a DM. *JeromyBingham          |1317624          |1317626                |@426997 we want to make sure you have all the information about your order. let's take a look, send us a dm. *jeromybingham          |
# |2025-06-27 12:57:26.819|1317628 |426998     |true   |Fri Oct 27 07:53:52 +0000 2017|@426997 nah going to store I need it on the 3rd                                                                                      |1317627          |1317629                |@426997 nah going to store i need it on the 3rd                                                                                      |
# |2025-06-27 12:57:26.819|1317629 |426997     |true   |Fri Oct 27 07:52:10 +0000 2017|@426998 Why bruh, keep trying                                                                                                        |1317628          |1317630                |@426998 why bruh, keep trying                                                                                                        |
# |2025-06-27 12:57:26.819|1317631 |426997     |true   |Fri Oct 27 07:47:19 +0000 2017|@426998 Got it bro, I dunno if I should go back to sleep or just wait and go to work early lol                                       |1317630          |1317632                |@426998 got it bro, i dunno if i should go back to sleep or just wait and go to work early lol                                       |
# |2025-06-27 12:57:26.819|1317632 |426998     |true   |Fri Oct 27 07:35:06 +0000 2017|@426997 I might have to go to the store early to get one                                                                             |1317631          |1317633                |@426997 i might have to go to the store early to get one                                                                             |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Remove punctuation

# %%
df_twcs_clean = df_twcs_clean.withColumn(
    "text_clean", regexp_replace(col("text"), r"[^\w\s]", "")
)

df_twcs_clean.show(10, truncate=False)
# Out:
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+---------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |tweet_id|author_id  |inbound|created_at                    |text                                                                                                                                 |response_tweet_id|in_response_to_tweet_id|text_clean                                                                                                                       |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+---------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-27 12:57:26.818|1317615 |TMobileHelp|false  |Fri Oct 27 08:13:27 +0000 2017|@427759 What's going on, Hadas? *NaeJ                                                                                                |                 |1317616                |427759 Whats going on Hadas NaeJ                                                                                                 |
# |2025-06-27 12:57:26.818|1317618 |TMobileHelp|false  |Fri Oct 27 08:13:25 +0000 2017|@427761 https://t.co/xKtJVNqc2V *RileyRed                                                                                            |                 |1317619                |427761 httpstcoxKtJVNqc2V RileyRed                                                                                               |
# |2025-06-27 12:57:26.818|1317621 |427762     |true   |Fri Oct 27 08:08:53 +0000 2017|@115911 Hi there. I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email. Is that normal?|1317619,1317622  |                       |115911 Hi there I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email Is that normal|
# |2025-06-27 12:57:26.818|1317620 |TMobileHelp|false  |Fri Oct 27 08:13:21 +0000 2017|@427761 If you can confirm your account for me I can jump right in! *RileyRed                                                        |                 |1317619                |427761 If you can confirm your account for me I can jump right in RileyRed                                                       |
# |2025-06-27 12:57:26.818|1317623 |TMobileHelp|false  |Fri Oct 27 08:13:19 +0000 2017|@426997 I see your DM and will be responding shortly. Thanks for hanging in there with us. *JeromyBingham                            |                 |1317624                |426997 I see your DM and will be responding shortly Thanks for hanging in there with us JeromyBingham                            |
# |2025-06-27 12:57:26.818|1317625 |TMobileHelp|false  |Fri Oct 27 08:02:48 +0000 2017|@426997 We want to make sure you have all the information about your order. Let's take a look, send us a DM. *JeromyBingham          |1317624          |1317626                |426997 We want to make sure you have all the information about your order Lets take a look send us a DM JeromyBingham            |
# |2025-06-27 12:57:26.819|1317628 |426998     |true   |Fri Oct 27 07:53:52 +0000 2017|@426997 nah going to store I need it on the 3rd                                                                                      |1317627          |1317629                |426997 nah going to store I need it on the 3rd                                                                                   |
# |2025-06-27 12:57:26.819|1317629 |426997     |true   |Fri Oct 27 07:52:10 +0000 2017|@426998 Why bruh, keep trying                                                                                                        |1317628          |1317630                |426998 Why bruh keep trying                                                                                                      |
# |2025-06-27 12:57:26.819|1317631 |426997     |true   |Fri Oct 27 07:47:19 +0000 2017|@426998 Got it bro, I dunno if I should go back to sleep or just wait and go to work early lol                                       |1317630          |1317632                |426998 Got it bro I dunno if I should go back to sleep or just wait and go to work early lol                                     |
# |2025-06-27 12:57:26.819|1317632 |426998     |true   |Fri Oct 27 07:35:06 +0000 2017|@426997 I might have to go to the store early to get one                                                                             |1317631          |1317633                |426997 I might have to go to the store early to get one                                                                          |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+---------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Remove stopwords

# %%
stop_words_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")

df_twcs_clean = df_twcs_clean.withColumn("words", split(col("text_clean"), " ")) \
                  .transform(stop_words_remover.transform) \
                  .withColumn("text_clean", concat_ws(" ", col("filtered_words"))) \
                  .drop("words", "filtered_words")

# %%
df_twcs_clean.show(10, truncate=False)
# Out:
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------+
# |timestamp_kafka        |tweet_id|author_id  |inbound|created_at                    |text                                                                                                                                 |response_tweet_id|in_response_to_tweet_id|text_clean                                                                      |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------+
# |2025-06-27 12:57:26.818|1317615 |TMobileHelp|false  |Fri Oct 27 08:13:27 +0000 2017|@427759 What's going on, Hadas? *NaeJ                                                                                                |                 |1317616                |427759 Whats going Hadas NaeJ                                                   |
# |2025-06-27 12:57:26.818|1317618 |TMobileHelp|false  |Fri Oct 27 08:13:25 +0000 2017|@427761 https://t.co/xKtJVNqc2V *RileyRed                                                                                            |                 |1317619                |427761 httpstcoxKtJVNqc2V RileyRed                                              |
# |2025-06-27 12:57:26.818|1317621 |427762     |true   |Fri Oct 27 08:08:53 +0000 2017|@115911 Hi there. I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email. Is that normal?|1317619,1317622  |                       |115911 Hi spoke rep place iPhone X order received sort confirmation email normal|
# |2025-06-27 12:57:26.818|1317620 |TMobileHelp|false  |Fri Oct 27 08:13:21 +0000 2017|@427761 If you can confirm your account for me I can jump right in! *RileyRed                                                        |                 |1317619                |427761 confirm account jump right RileyRed                                      |
# |2025-06-27 12:57:26.818|1317623 |TMobileHelp|false  |Fri Oct 27 08:13:19 +0000 2017|@426997 I see your DM and will be responding shortly. Thanks for hanging in there with us. *JeromyBingham                            |                 |1317624                |426997 see DM responding shortly Thanks hanging us JeromyBingham                |
# |2025-06-27 12:57:26.818|1317625 |TMobileHelp|false  |Fri Oct 27 08:02:48 +0000 2017|@426997 We want to make sure you have all the information about your order. Let's take a look, send us a DM. *JeromyBingham          |1317624          |1317626                |426997 want make sure information order Lets take look send us DM JeromyBingham |
# |2025-06-27 12:57:26.819|1317628 |426998     |true   |Fri Oct 27 07:53:52 +0000 2017|@426997 nah going to store I need it on the 3rd                                                                                      |1317627          |1317629                |426997 nah going store need 3rd                                                 |
# |2025-06-27 12:57:26.819|1317629 |426997     |true   |Fri Oct 27 07:52:10 +0000 2017|@426998 Why bruh, keep trying                                                                                                        |1317628          |1317630                |426998 bruh keep trying                                                         |
# |2025-06-27 12:57:26.819|1317631 |426997     |true   |Fri Oct 27 07:47:19 +0000 2017|@426998 Got it bro, I dunno if I should go back to sleep or just wait and go to work early lol                                       |1317630          |1317632                |426998 Got bro dunno go back sleep wait go work early lol                       |
# |2025-06-27 12:57:26.819|1317632 |426998     |true   |Fri Oct 27 07:35:06 +0000 2017|@426997 I might have to go to the store early to get one                                                                             |1317631          |1317633                |426997 might go store early get one                                             |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Tokenization

# %%
df_twcs_clean = df_twcs_clean.withColumn(
    "tokens", 
    expr("filter(split(text_clean, ' '), x -> NOT x RLIKE '^[0-9]+$')")
)

df_twcs_clean.select("text_clean", "tokens").show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+
# |text_clean                                                                      |tokens                                                                                |
# +--------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+
# |427759 Whats going Hadas NaeJ                                                   |[Whats, going, Hadas, NaeJ]                                                           |
# |427761 httpstcoxKtJVNqc2V RileyRed                                              |[httpstcoxKtJVNqc2V, RileyRed]                                                        |
# |115911 Hi spoke rep place iPhone X order received sort confirmation email normal|[Hi, spoke, rep, place, iPhone, X, order, received, sort, confirmation, email, normal]|
# |427761 confirm account jump right RileyRed                                      |[confirm, account, jump, right, RileyRed]                                             |
# |426997 see DM responding shortly Thanks hanging us JeromyBingham                |[see, DM, responding, shortly, Thanks, hanging, us, JeromyBingham]                    |
# |426997 want make sure information order Lets take look send us DM JeromyBingham |[want, make, sure, information, order, Lets, take, look, send, us, DM, JeromyBingham] |
# |426997 nah going store need 3rd                                                 |[nah, going, store, need, 3rd]                                                        |
# |426998 bruh keep trying                                                         |[bruh, keep, trying]                                                                  |
# |426998 Got bro dunno go back sleep wait go work early lol                       |[Got, bro, dunno, go, back, sleep, wait, go, work, early, lol]                        |
# |426997 might go store early get one                                             |[might, go, store, early, get, one]                                                   |
# +--------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
df_twcs_clean.select("text_clean").show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------+
# |text_clean                                                                      |
# +--------------------------------------------------------------------------------+
# |427759 Whats going Hadas NaeJ                                                   |
# |427761 httpstcoxKtJVNqc2V RileyRed                                              |
# |115911 Hi spoke rep place iPhone X order received sort confirmation email normal|
# |427761 confirm account jump right RileyRed                                      |
# |426997 see DM responding shortly Thanks hanging us JeromyBingham                |
# |426997 want make sure information order Lets take look send us DM JeromyBingham |
# |426997 nah going store need 3rd                                                 |
# |426998 bruh keep trying                                                         |
# |426998 Got bro dunno go back sleep wait go work early lol                       |
# |426997 might go store early get one                                             |
# +--------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# Create label

# %%
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon
# Out:
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %%
positive_keywords = list(opinion_lexicon.positive())
negative_list = list(opinion_lexicon.negative())
custom_negative = ["sucks", "bad", "hate", "worst", "terrible", "awful", "disappointing", "fuck", "shit"]
negative_keywords = negative_list + custom_negative

df_twcs_clean = df_twcs_clean.withColumn(
    "sentiment",
    when(
        size(array_intersect(col("tokens"), array([lit(x) for x in positive_keywords]))) > 0, "positive"
    ).when(
        size(array_intersect(col("tokens"), array([lit(x) for x in negative_keywords]))) > 0, "negative"
    ).otherwise("neutral")
)

# %%
df_twcs_clean.select("author_id","text_clean", "sentiment").show(1000, truncate=False)
# Out:
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |author_id      |text_clean                                                                                                                                |sentiment|
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |TMobileHelp    |427759 Whats going Hadas NaeJ                                                                                                             |neutral  |
# |TMobileHelp    |427761 httpstcoxKtJVNqc2V RileyRed                                                                                                        |neutral  |
# |427762         |115911 Hi spoke rep place iPhone X order received sort confirmation email normal                                                          |neutral  |
# |TMobileHelp    |427761 confirm account jump right RileyRed                                                                                                |positive |
# |TMobileHelp    |426997 see DM responding shortly Thanks hanging us JeromyBingham                                                                          |neutral  |
# |TMobileHelp    |426997 want make sure information order Lets take look send us DM JeromyBingham                                                           |neutral  |
# |426998         |426997 nah going store need 3rd                                                                                                           |neutral  |
# |426997         |426998 bruh keep trying                                                                                                                   |neutral  |
# |426997         |426998 Got bro dunno go back sleep wait go work early lol                                                                                 |positive |
# |426998         |426997 might go store early get one                                                                                                       |neutral  |
# |426998         |426997 115911 keep trying                                                                                                                 |neutral  |
# |TMobileHelp    |427763 115913 Thanks working us DM Well meet HollyAdams                                                                                   |neutral  |
# |427763         |115913 love 115911 online customer service anymore waiting 1 hour nothing person ust disappeared                                          |positive |
# |TMobileHelp    |207219 Anytime Andre  ya need us VictorNunn                                                                                               |neutral  |
# |207219         |115911 Thanks breeze preorder iPhone X D                                                                                                  |positive |
# |TMobileHelp    |427764 Hello Oh Please send us DM love revise order set success  ThaniaR                                                                  |positive |
# |TMobileHelp    |427765 Thank much amazing Paris IzzyMint                                                                                                  |positive |
# |427765         |427766 115911 Neither cost much TMobile                                                                                                   |neutral  |
# |427766         |427765 115911 Youre getting iPhone X 8 Plus                                                                                               |neutral  |
# |427765         |Thanks 115911 httpstcofWq7Kb7F6o                                                                                                          |neutral  |
# |TMobileHelp    |427762 Shoot DM right Id happy review account details SusanaDominguez                                                                     |positive |
# |427762         |427767 115911 Im glad Im one info TMobile portal either                                                                                   |positive |
# |427767         |427762 115911 problem email confirmation 15 min                                                                                           |negative |
# |TMobileHelp    |427769 115913 Lets take make sure account right DMing soon                                                                                |positive |
# |TMobileHelp    |427769 115913 see DM responding shortly want ensure best options available today JeromyBingham                                            |positive |
# |424787         |427769 115913 115911 115725 ATT Agreed Complete bait switch JOD customers Total joke                                                      |negative |
# |427769         |115913 115911 115725 ATT happen great trade deal iPhone X 300 trade Jump Program BS                                                       |positive |
# |TMobileHelp    |427770 115913 Hey Steven Lets make sure place line confirmed DM us NicholasTomchik                                                        |neutral  |
# |427770         |374333 115911 115913 Sounds right got reservation confirmation page number email                                                          |positive |
# |374333         |Still waiting confirmation email even get email right phone iPhoneX httpstcorAyrxQ23qA                                                    |positive |
# |TMobileHelp    |427771 115913 Well meet DM get straightened Please send us message RachaelTansey                                                          |neutral  |
# |427771         |TMobileHelp 115913 jump demand program learn get 0 4156 iPhone x 64 GB new rules 3 years                                                  |neutral  |
# |427772         |427771 TMobileHelp 115913 3 years tell something else think lie 115911                                                                    |negative |
# |TMobileHelp    |427771 115913 want make sure information placing order Lets take look send us DM JeromyBingham                                            |neutral  |
# |427771         |TMobileHelp 115913 call                                                                                                                   |neutral  |
# |TMobileHelp    |427771 115913 want able preorder iPhone X little pocket possible DM us weve got back ShelbyMartin                                         |neutral  |
# |427771         |115913 \nHi John royal customer two years Tonight learn upgrade iPhone x 0 payment jump dema                                              |neutral  |
# |TMobileHelp    |427148 115913 115911 Thanks letting us know see DM well following shortly help RachaelTansey                                              |positive |
# |427148         |115913 115911  keep trying  get fixed actually preorder iPhone X  Stayed night nothing                                                    |neutral  |
# |TMobileHelp    |351235 115911 115913 Wed love chance turn around see DM meet back CassyFitzgerald                                                         |positive |
# |351235         |TMobileHelp 115911 115913 Executive Team contact                                                                                          |neutral  |
# |TMobileHelp    |427773 115913 want make sure order placed DM Ill help HollyAdams                                                                          |neutral  |
# |427773         |TMobileHelp 115913 went back bed rep said call Highly doubtful turn devices move                                                          |negative |
# |TMobileHelp    |427773 115913 absolutely dont want see go Please DM us help httpstcocuEwtd2epS DanKing                                                    |neutral  |
# |427773         |TMobileHelp 115913 wait see Rep calls employee                                                                                            |neutral  |
# |TMobileHelp    |427773 115913 Know 247 always happy help DM us anytime httpstcocuEwtd2epS DanKing                                                         |positive |
# |427774         |427773 TMobileHelp 115913 great experience 115725 getting mine November 10 ordering snap                                                  |positive |
# |427773         |427774 TMobileHelp 115913 115725 Thanks Jose                                                                                              |neutral  |
# |427773         |115913 Every year system crashes new iPhone comes hope future mobile better prepared Order completeOops get                               |positive |
# |TMobileHelp    |364701 115913 Hey Zander Lets talk Please DM us help NicholasTomchik                                                                      |neutral  |
# |364701         |TMobileHelp 115913 Sent                                                                                                                   |neutral  |
# |TMobileHelp    |191660 115913 115911 Thanks letting us know Well following moment RachaelTansey                                                           |neutral  |
# |191660         |115913 115911 Dm sent                                                                                                                     |neutral  |
# |TMobileHelp    |427775 115913 115911 certainly dont want waiting  DM lets check httpstcoksErEeh6LL RayButler                                              |neutral  |
# |TMobileHelp    |427579 115913 115911 see DM Well meet HollyAdams                                                                                          |neutral  |
# |TMobileHelp    |173265 115913 see working DM Well meet HollyAdams                                                                                         |neutral  |
# |173265         |115913 TForce lied ashamed preorder process horrible Still order payment                                                                  |negative |
# |TMobileHelp    |427754 Please follow link httpstcoC9u7AU8oQE GeraldB                                                                                      |neutral  |
# |TMobileHelp    |427754 iPhone Android device computer type GeraldB                                                                                        |neutral  |
# |TMobileHelp    |427754 115911 Send us DM TForce GeraldB                                                                                                   |neutral  |
# |427754         |115911 someone help iPhone x pre order                                                                                                    |neutral  |
# |TMobileHelp    |427776 Hey Brady please send DM check  VickyHernandez                                                                                     |neutral  |
# |427776         |TMobileHelp thanks                                                                                                                        |neutral  |
# |427776         |TMobileHelp JumpOnDemand 0 option iPhone X                                                                                                |neutral  |
# |TMobileHelp    |374333 115913 came right place make order happen right see DM respond AdrenaBentley                                                       |positive |
# |TMobileHelp    |427777 Hey Erika trouble Shoot us DM well happy help AshlynW                                                                              |positive |
# |424902         |got thanks 115911 httpstcoWgqbLRmsld                                                                                                      |neutral  |
# |TMobileHelp    |427778 Im DM help still Ill see back get resolved AustinWebb                                                                              |neutral  |
# |427778         |TMobileHelp said get iPhone x zero try order want charge 300                                                                              |neutral  |
# |TMobileHelp    |427779 message way receiving shortly KatieM                                                                                               |neutral  |
# |TMobileHelp    |427780 Hey Susan send us DM well make sure get taken care ErikS                                                                           |positive |
# |115911         |427781 Thanks patience right Ivan NaeJ                                                                                                    |positive |
# |427781         |115911 Already 20 minutes ago response                                                                                                    |neutral  |
# |115911         |427781 got back Ivan Send us DM TMobileHelp get everything processed TarynS                                                               |neutral  |
# |427781         |115911 shows problem                                                                                                                      |negative |
# |115911         |427781 tried upgrading via TMobile app Ivan also DM us TMobileHelp assistance TerriL                                                      |neutral  |
# |427781         |115911 tired pre ordering shows iPhone 87 website                                                                                         |negative |
# |TMobileHelp    |427782 115913 want get taken care  DM lets chat httpstco93XwcSKFIy RayButler                                                              |neutral  |
# |427782         |115913 Disappointed sudden change 0 jump demand 280 Even told 0                                                                           |neutral  |
# |TMobileHelp    |378310 Hey Sean Lets make sure preorder taken care Send us DM check TianaG                                                                |neutral  |
# |TMobileHelp    |362515 Thanks DM well following moment get order placed RachaelTansey                                                                     |positive |
# |362515         |TMobileHelp Dm sent  one answers                                                                                                          |neutral  |
# |TMobileHelp    |362515 got Juan Send us DM upgrade needs RickK                                                                                            |neutral  |
# |362515         |115911 able Help                                                                                                                          |neutral  |
# |TMobileHelp    |304626 Hello  super excited iPhone X  TMobile great offers  Send us DM discuss DeniseP                                                    |positive |
# |304626         |427783 TMobileHelp ATampT lets order phones without get tacked bill pay                                                                   |neutral  |
# |TMobileHelp    |427784 love look DM assistance CorineB                                                                                                    |positive |
# |427784         |tmobilehelp placed preorder still havent gotten emails sign EIP JOD order                                                                 |neutral  |
# |TMobileHelp    |427785 Hey Bex working DMs help get taken care Ill catch JoshuaB                                                                          |neutral  |
# |427785         |TMobileHelp ignored                                                                                                                       |neutral  |
# |TMobileHelp    |427786 see DM meet SonjaKett                                                                                                              |neutral  |
# |427786         |TMobileHelp already sent DM reply                                                                                                         |neutral  |
# |TMobileHelp    |427786 Lets get right spot Send DM help httpstcoyZ5k0mtFsX SonjaKett                                                                      |positive |
# |427786         |115911 TMobileHelp Ive trying order IPhone X hour nowbut gives option select iPhone 7 amp 8 Help httpstcouVP76pHPgj                       |neutral  |
# |TMobileHelp    |427787 115913 Hey John help ensure things smooth amp help order DM us NicholasTomchik                                                     |positive |
# |427787         |TMobileHelp 115913 done response IphoneXPreOrder                                                                                          |neutral  |
# |TMobileHelp    |427787 115913 sent DM way Ill meet HollyAdams                                                                                             |neutral  |
# |TMobileHelp    |427027 115913 Coverage joke appreciate time worked us respond DM AdrenaBentley                                                            |positive |
# |427027         |115913 hope u towers 80631 updated tomorrow reach fcc annoyed w ur biz practice                                                           |negative |
# |TMobileHelp    |427788 Thanks patience Well shortly JasmineS                                                                                              |positive |
# |427788         |115911 still answer                                                                                                                       |neutral  |
# |Morrisons      |427789 Thanks Matt   Nisha                                                                                                                |neutral  |
# |Delta          |427790 upsetting see let need assistance please followDM confirmation number AMV                                                          |negative |
# |427790         |5 hour flight delay hooks bathroom stalls amp 75 ur charging stations dont work Delta get ur shit together                                |positive |
# |SpotifyCares   |427791 Hey Evie Weve sent bit info DM Well carry helping TC                                                                               |positive |
# |427791         |117153 Please help paid spotify premium hour ago still working already sent DM thank                                                      |positive |
# |117153         |investigating payment issues working hard get things fixed Well provide updates receive                                                   |negative |
# |SpotifyCares   |427792 Hey launching new countries often possible sure add email httpstcoX8DVSX9QgM GK                                                    |neutral  |
# |427792         |115888 guys please launch app inIndia Got chance experience app LIT need                                                                  |neutral  |
# |AmericanAir    |427407 AATeam loves taking care Lisa hope see soon                                                                                        |positive |
# |427407         |AmericanAir HUGE shout team servicing First AA90 yesterday Bloody fantastic Thanks great flight Lisa 3H                                   |positive |
# |comcastcares   |427793 definitely help check status services please DM address phone number proceed NFM                                                   |neutral  |
# |427793         |comcastcares Oh back somebody company planned poorly timing                                                                               |negative |
# |comcastcares   |427793 Understood Im glad hear services working need help anything else reach us anytime NFM                                              |positive |
# |427793         |Really comcastcares  new iPhones go sale tether httpstcovvx1izDDwM                                                                        |neutral  |
# |sprintcare     |427794 Hello sorry hear Please contact us Direct Message Well like assist  SB                                                             |positive |
# |427794         |sprintcare straight awful month prepare launch course sprint screws                                                                       |negative |
# |Morrisons      |427795 Hey Laura Ive replied DM  Rebecca                                                                                                  |neutral  |
# |427795         |Morrisons sent dm                                                                                                                         |neutral  |
# |sprintcare     |427796 Please try using website httpstco0qBF3Cekat maintenance completed JC                                                               |neutral  |
# |sprintcare     |427797 Hey excited iPhone X platform maintenance till 300 CT may try JA                                                                   |positive |
# |427798         |sprintcare 427797 313 CT                                                                                                                  |neutral  |
# |sprintcare     |427797 truly appreciate patience page saturated due high demand Iphone X JA                                                               |positive |
# |427797         |sprintcare Ive trying get iPhone X hourplease Help                                                                                        |neutral  |
# |sprintcare     |174495 understand concerns Unfortunately upgrade waived device AH                                                                         |negative |
# |174495         |sprintcare told phone day guys really sleazy need credited back                                                                           |negative |
# |427620         |sprintcare 174495 lol                                                                                                                     |neutral  |
# |174495         |41783 Really wanna vent hard 115714s crazy sleaze tactics tonight trying send good karma universe                                         |positive |
# |sprintcare     |315822 encourage keep trying  DW                                                                                                          |positive |
# |315822         |sprintcare app says httpstcoCaR34lLsxa                                                                                                    |neutral  |
# |427603         |315822 sprintcare                                                                                                                         |neutral  |
# |sprintcare     |315822 Im sorry youre experiencing issues performing maintenance everything good  DW                                                      |positive |
# |315822         |427799 115714 sprintcare Right wanted give                                                                                                |neutral  |
# |sprintcare     |427241 Website running Please try gain access different web browser MD                                                                    |positive |
# |427800         |sprintcare 427241 working                                                                                                                 |neutral  |
# |427801         |sprintcare 427241 Im using 3 browsers 1 hour Im stuck lobby page one                                                                      |negative |
# |427620         |sprintcare 427241 nope safari chrome working                                                                                              |neutral  |
# |sprintcare     |427417 working Please refresh page LNL                                                                                                    |positive |
# |427802         |sprintcare 427417 DAMN WORKING SINCE 250 HASNT WORKED                                                                                     |neutral  |
# |427803         |sprintcare 427417  httpstcoLnJKg7OjWi                                                                                                     |neutral  |
# |362509         |sprintcare 427417 Still broke                                                                                                             |negative |
# |sprintcare     |362509 Please send us DM follow us provide assistance matter  RC                                                                          |neutral  |
# |427804         |sprintcare 427417 Still working                                                                                                           |neutral  |
# |sprintcare     |427803 see website maintenance 0300AM advise try OM                                                                                       |neutral  |
# |sprintcare     |427805 time web page maintenance right department working fix soon possible FP                                                            |positive |
# |427805         |sprintcare make servers work                                                                                                              |positive |
# |sprintcare     |427805 apologize inconvenience Please send us DM assist FP                                                                                |negative |
# |427805         |Also unlike sprintcare coffee maker works time Apple iPhoneX SprintSucks httpstcopzVt1iHiZd                                               |positive |
# |315822         |sprintcare happens check httpstcop6pMlIu5d8                                                                                               |neutral  |
# |427603         |sprintcare 315822 Lies httpstcoxfASt9DxGG                                                                                                 |neutral  |
# |427620         |sprintcare 315822 keep refreshing wait                                                                                                    |positive |
# |sprintcare     |427806 Team 116447 Send us DM contact info need help                                                                                      |neutral  |
# |sprintcare     |427807 Thank patience DMs take closer look  Team 116447                                                                                   |positive |
# |427807         |sprintcare 116447 get response                                                                                                            |neutral  |
# |427612         |sprintcare 315822 Still working managed get till checkout page crapped saying send text 2step verification                                |neutral  |
# |315822         |427612 sprintcare                                                                                                                         |neutral  |
# |sprintcare     |427612 order us assist please send us DM                                                                                                  |neutral  |
# |sprintcare     |427808 Please refresh keep trying sorry mishaps AC                                                                                        |positive |
# |sprintcare     |427808 line please continue let us know error displaying AC                                                                               |negative |
# |sprintcare     |427808 sain Line inside website waiting process please confirm AC                                                                         |neutral  |
# |427620         |sprintcare 427808 Youre line iPhone X\nOh anticipation\n\nWe know phones going sell like hotcakes keep browser window ope                 |positive |
# |sprintcare     |427808 Please proceed refresh let us know outcome AC                                                                                      |positive |
# |427605         |sprintcare 427808 clueless Sprint suck WOW                                                                                                |negative |
# |427620         |sprintcare 427808 line colorful page says u cant order yet                                                                                |positive |
# |427810         |sprintcare 427808  httpstco14ST3mX3ix                                                                                                     |neutral  |
# |427413         |sprintcare 427808 fucking crazy                                                                                                           |negative |
# |427811         |sprintcare 427808 Showing stock                                                                                                           |neutral  |
# |sprintcare     |427811 427808 Hello saw message want take look concern Please follow us sprintcare DM back  YM                                            |negative |
# |sprintcare     |427811 427808 Hello saw message want take look concern Please follow us sprintcare DM back                                                |negative |
# |425036         |sprintcare need help says unavailable add cart                                                                                            |negative |
# |427811         |sprintcare 427808 Done                                                                                                                    |neutral  |
# |427812         |sprintcare mine keeps going failing                                                                                                       |negative |
# |427808         |115714 better get iphone 3rd crap put us                                                                                                  |positive |
# |427803         |sprintcare  httpstcoIe0PSjkwgf                                                                                                            |neutral  |
# |427803         |sprintcare  httpstcoY41j8w1KwG                                                                                                            |neutral  |
# |427813         |sprintcare 427803 Still broken  tired  get act together go back sleep                                                                     |negative |
# |427247         |sprintcare 427803 Still waiting Get entire team start revving servers max capacity                                                        |neutral  |
# |sprintcare     |427430 Thank letting us know website back expected MK                                                                                     |neutral  |
# |427801         |sprintcare 427430 isnt submitting payment site crashed dont know took money                                                               |negative |
# |427430         |427801 sprintcare way knew near instant credit card preauth notif credit card  116016  da real MVP                                        |neutral  |
# |ChaseSupport   |427430 Thanks shoutout questions please let us know RS                                                                                    |neutral  |
# |sprintcare     |427235 Hey Give try 300 KT                                                                                                                |neutral  |
# |sprintcare     |427814 understand might feel excited new iPhone X try maintenance  RC                                                                     |positive |
# |427814         |sprintcare Yep site still crashing attempting checkout                                                                                    |negative |
# |427815         |sprintcare 427814 bullshit maintenance done launch actually going work                                                                    |positive |
# |427814         |sprintcare back waiting line Seriously screenshot cart  kicked checkout 5 times httpstco5KgWfMAku9                                        |neutral  |
# |427816         |427814 sprintcare got past part wanted send codes 4 times said couldnt send codes go store 4am                                            |neutral  |
# |sprintcare     |427817 Excited IPhone X well JC                                                                                                           |positive |
# |427817         |iPhoneX 115714 site always showing unavailable try get iphone pls send help SOS                                                           |negative |
# |sprintcare     |427818 Please attempt access website Let us know able AC                                                                                  |neutral  |
# |427818         |115714 fuck yall                                                                                                                          |negative |
# |VirginTrains   |427819 agree  BT                                                                                                                          |neutral  |
# |427819         |Worst diet ever VirginTrains httpstco5or1KmEu2C                                                                                           |neutral  |
# |427820         |sent message DropboxSupport  thanks advance                                                                                               |neutral  |
# |DropboxSupport |427821 Hey David replying DM thanks bearing us                                                                                            |neutral  |
# |427821         |DropboxSupport ive got problem messaged u guys long take get answer                                                                       |negative |
# |427823         |O2 deals way EE though phone                                                                                                              |neutral  |
# |O2             |427823 phone looking Stephen spoken upgrades team directly see                                                                            |neutral  |
# |427823         |O2 iPhone 7 unlimited text mins 5gb data free phone 3299 EE o2 1999 phone  40 month 3gb data chat unless fampf wont deal                  |positive |
# |O2             |427823 Ah okay sorry unable offer deal looking                                                                                            |negative |
# |427823         |O2 loyalty price match maybe 118101 come much easier stay pay less                                                                        |positive |
# |427824         |O2 better winning O2Priority friends httpstcoO2Am1h8W5y                                                                                   |positive |
# |British_Airways|418875 looking forward welcoming board Dann Linda                                                                                         |neutral  |
# |O2             |427825 customers equally important us contracts due renewal                                                                               |positive |
# |O2             |427825 Ah okay Give us shout bit closer time wed love help                                                                                |positive |
# |VirginTrains   |136123 DM us please Elliot take look CB httpstcohhfk9c3ylv                                                                                |neutral  |
# |136123         |VirginTrains done                                                                                                                         |neutral  |
# |136123         |VirginTrains come website says Bus Service                                                                                                |neutral  |
# |VirginTrains   |136123 still services running Liverpool Lime Street weekend CB                                                                            |neutral  |
# |136123         |VirginTrains Hello whats happening Lime Street weekend buses running Runcorn Widnes                                                       |neutral  |
# |VirginTrains   |282132 Thank sharing us Stacey CB                                                                                                         |neutral  |
# |VirginTrains   |282132 certainly CB                                                                                                                       |neutral  |
# |VirginTrains   |334539 stage expect service run Live updates posted httpstco7nD5fiEgKc CB                                                                 |neutral  |
# |334539         |VirginTrains keep fingers paws crossed aim one  thanks quick response   hope day isnt painful 4u CB                                       |negative |
# |334539         |VirginTrains due 1130 BhamNewSt Watford going running know whats alternative                                                              |neutral  |
# |VirginTrains   |336848 Staff station best placed assist CB                                                                                                |positive |
# |336848         |VirginTrains One last thing promise 0937 WVH GLC 11 car Pendo                                                                             |positive |
# |VirginTrains   |336848 11 car CB                                                                                                                          |neutral  |
# |336848         |VirginTrains U unreserved coach                                                                                                           |neutral  |
# |VirginTrains   |336848 U C unreserved CB                                                                                                                  |neutral  |
# |336848         |121428 VirginTrains VirginTrains told get Wolverhampton VT please help                                                                    |neutral  |
# |121428         |336848 VirginTrains ticket acceptance direction Virgin Trains sorry RS                                                                    |negative |
# |336848         |Hi 121428 ticket acceptance VirginTrains BHM Wolves                                                                                       |neutral  |
# |VirginTrains   |427826 expect service depart next 10 minutes CB                                                                                           |neutral  |
# |427826         |VirginTrains sitting 830 Euston still  birmingham chance leaving                                                                          |neutral  |
# |VirginTrains   |426663 DM us please Martin CB httpstcohhfk9c3ylv                                                                                          |neutral  |
# |426663         |VirginTrains sending unsolicited emails declined settings                                                                                 |neutral  |
# |427828         |O2 Theres reason stayed guys 6 years 121122 awful far misleading                                                                          |negative |
# |427828         |121122 Yep perharps charging customer moved O2 864 extra data charges unable top data allowance abroad                                    |positive |
# |121122         |427828 Hi Olly theres anything assist please let us know Kirsty                                                                           |neutral  |
# |427828         |121122 wont charge data abroad charge 864 extra data charges let top 4G joke                                                              |positive |
# |Ask_Spectrum   |427829 apologize delayed response able get account CM                                                                                     |negative |
# |Ask_Spectrum   |427829 apologize speaking phone representative review account  httpstcogwjmeL7DmH                                                         |neutral  |
# |427829         |Ask_Spectrum Yes Thank attentive                                                                                                          |positive |
# |Ask_Spectrum   |427829 Youre welcome need information review send information private message httpstcogwjmeL7DmH                                          |positive |
# |427829         |Ask_Spectrum necessary make us wait 1 hr locking us accounts imisstwc neverthoughtidsaythat                                               |neutral  |
# |MicrosoftHelps |427830 Hi Lets work together version Windows running getting error messages                                                               |positive |
# |427830         |116230 task manager always crash                                                                                                          |negative |
# |GWRHelp        |130097 get reported right away Rach                                                                                                       |positive |
# |130097         |GWRHelp want refund ridiculous                                                                                                            |positive |
# |GWRHelp        |130097 delayed hour claim compensation httpstcokZncdam7bx Rach                                                                            |negative |
# |GWRHelp        |130097 next available service 0920 22 Rach                                                                                                |positive |
# |GWRHelp        |130097 Hi Jessi Apologies cancellation morning train cancelled train fault 12 Rach                                                        |negative |
# |GWRHelp        |427831 Hi MarieAnn Apologies delay service travel Lewis                                                                                   |negative |
# |GWRHelp        |427831 try prevent sorts cancellations much possible sometimes option Sorry problems caused Lewis                                         |negative |
# |marksandspencer|427832 let us know store well share feedback Thanks 22                                                                                    |positive |
# |marksandspencer|427832 Sorry youre disappointed Seamus like manned tills self service ones give whats float 12                                            |positive |
# |KFC_UKI_Help   |427833 Hi Chris Sorry hear Please Dm us info look KR                                                                                      |neutral  |
# |KFC_UKI_Help   |427834 Hi Chloe Sorry hear imagine disappointment expect KR                                                                               |negative |
# |427834         |Imagine queuing 35 min 120984 amp saying chicken queue door  Biggest time waste ever                                                      |negative |
# |KFC_UKI_Help   |427835 Hi Sorry send us DM well best resolve KR                                                                                           |positive |
# |KFC_UKI_Help   |427835 Sorry followed thisGB                                                                                                              |neutral  |
# |427835         |Dont want fastfood dont want hot 120984 longwater place go nice 40 minute build disappointment                                            |positive |
# |KFC_UKI_Help   |427836 Hi Sasi Sorry hear please DM us try put right KR                                                                                   |positive |
# |427836         |KFC_UKI_Help Done                                                                                                                         |neutral  |
# |Morrisons      |121889 Hi Chrissie please DM store  Thanks Dilly                                                                                          |neutral  |
# |KFC_UKI_Help   |124630 Hi Jess Please DM us discuss KR                                                                                                    |neutral  |
# |KFC_UKI_Help   |124630 Sorry please try againSB                                                                                                           |neutral  |
# |KFC_UKI_Help   |427837 HI Peter Sorry hear please DM us look KR                                                                                           |neutral  |
# |427837         |KFC accepting cards bank go back queue 25 mins get home popcorn chicken order  KFC_UKI_Help complaint httpstcotLjO9HIgqn                  |negative |
# |427664         |118101 Faster Twitter aswell O2  need sort customer service                                                                               |neutral  |
# |118101         |427664 Dreams come true Harry well covered Remember take advantage perks httpstco1uqdvuzluX   Robyn                                       |positive |
# |427664         |O2 trying painful experience ever giving 118101                                                                                           |negative |
# |406834         |O2 confirmation purchase email Luckily logging getting ready 8am saw pre orders started                                                   |positive |
# |O2             |427668 team investigating similar reports please try later                                                                                |neutral  |
# |427668         |o2 customer 10 im really disappointed  card details wont go 6 weeks wait please rectify                                                   |positive |
# |O2             |427839 youve placed one order youll automatically refunded                                                                                |positive |
# |O2             |427839 one order confirmed pending charge order returned bank account                                                                     |neutral  |
# |O2             |427839 online order hasnt actually finished thats case money returned automatically                                                       |neutral  |
# |O2             |427840 Hi Todd certainly help date concert receive email confirmation                                                                     |neutral  |
# |427840         |O2 Hi sorry mess around managed sort Thanks reply though                                                                                  |negative |
# |427840         |O2 \nHi there\nI bought tickets rag amp bone man concert via app havent received yet u help                                               |neutral  |
# |O2             |427841 Please drop us DM info httpstco5pyLDJBC6r                                                                                          |neutral  |
# |427841         |O2 o2 manages Capita contract handles complaints need direct number email address specific person cheers                                  |negative |
# |427841         |O2 need complain contractor Capita information need know damage brand contact                                                             |negative |
# |427664         |O2 Cant see card details screen Pre Order IPhone X  Sort                                                                                  |neutral  |
# |O2             |427842 Weve replied private message                                                                                                       |neutral  |
# |427843         |O2 keep getting error messages online phone                                                                                               |negative |
# |O2             |427843 error message getting exactly DM us screenshot httpstco5pyLDJBC6r                                                                  |negative |
# |427843         |O2 seriously neither web top phone top work One think conning customers topping time 4 bundles                                            |positive |
# |427844         |O2 argue o2 phone reinstated poor customer experience manager wouldnt listenTGIF                                                          |negative |
# |O2             |427845 looking speak Jack please try soon                                                                                                 |neutral  |
# |427277         |O2 427845 GETTING FIRST STARTED DELIVERY 3RD NOV 4 WEEKS JOKE                                                                             |neutral  |
# |427846         |124248 O2 427845 issue card details part showing ad blocked one try disabling trying help                                                 |negative |
# ...
# |232240         |Jean dickhead amp Dawn cool thanks CoxHelp still waiting see Allen real name \n\nPs stranger things still sucks                           |positive |
# |CoxHelp        |427989 Oh look issue Please dm us full address help Thanks Allan                                                                          |negative |
# |427989         |hey CoxHelp wondering pay services theres internet outage least week                                                                      |neutral  |
# |Tesco          |273080 Hi Conor stores Northern Ireland open 12                                                                                           |neutral  |
# |Safaricom_Care |420586 Welcome MC                                                                                                                         |neutral  |
# |420586         |427990 Safaricom_Care Thank                                                                                                               |neutral  |
# |427990         |420586 Safaricom_Care Hi dial 100gtProducts n Servicesgt98 MoregtCaller notifygtManage BlacklistgtAdd BlacklistTo block particular callers|neutral  |
# |SW_Help        |427991 Hi Simon station referring please GV                                                                                               |neutral  |
# |427991         |SW_Help Arrived train station 820 still                                                                                                   |neutral  |
# |SW_Help        |427992 Hi sorry hear feed back station manager AW                                                                                         |negative |
# |427992         |SW_Help chaos Surbiton Funny guys little yellow jackets disappear issue staffMIA shockingcustomerservice                                  |negative |
# |SW_Help        |427993 morning AW 22                                                                                                                      |neutral  |
# |427993         |SW_Help broken train different line affect mine SUR crawled way WAT SouthWesternRailway waterloo                                          |negative |
# |SW_Help        |427994 Hi Tom thank kind feedback apologies delayed journey morning GV                                                                    |positive |
# |SW_Help        |427995 115793 hopefully managed get train ok sorry delays morning AW 22                                                                   |negative |
# |427995         |SW_Help 115793 Gave got bus tube partner cycled Trains got worse since lot took                                                           |negative |
# |LondonMidland  |414688 aim respond within 10 working days however take 20 busy periods                                                                    |neutral  |
# |LondonMidland  |414688 unfortunately staff member driver cancel service apologies inconvenience caused                                                    |negative |
# |LondonMidland  |414688 cancelled due member train crew unavailable sorry inconvenience caused                                                             |negative |
# |414688         |LondonMidland 813 Shifnal New St cancelled Train work cancelled 3x many weeks service poor Al                                             |positive |
# |LondonMidland  |427862 sure yet got tkt acceptance Chiltern want go Moor Street                                                                           |neutral  |
# |LondonMidland  |427862 believe 0955 service reinstated                                                                                                    |neutral  |
# |LondonMidland  |427862 reinstated                                                                                                                         |neutral  |
# |LondonMidland  |427862 reinstated different head code train jargon alert showing                                                                          |neutral  |
# |427862         |LondonMidland OK thank updates morning Much helpful automated announcements                                                               |positive |
# |427862         |LondonMidland rough ideas trains towards New St LDN run keep getting delayed seconds spare                                                |negative |
# |LondonMidland  |427996 present 0954 service running                                                                                                       |neutral  |
# |427996         |LondonMidland Running chaos little information                                                                                            |negative |
# |LondonMidland  |427996 Milton Keynes                                                                                                                      |neutral  |
# |427996         |LondonMidland                                                                                                                             |neutral  |
# |LondonMidland  |427996 Coventry                                                                                                                           |neutral  |
# |427996         |LondonMidland going straight change                                                                                                       |neutral  |
# |LondonMidland  |427996 scheduled run Coventry present                                                                                                     |neutral  |
# |427996         |LondonMidland OK Thank                                                                                                                    |neutral  |
# |427996         |LondonMidland told get Northampton  Please advise                                                                                         |neutral  |
# |LondonMidland  |427996 1025 next service Northampton Coventry                                                                                             |neutral  |
# |427996         |LondonMidland come cancelled  clarify Waiting Northampton hundreds people                                                                 |neutral  |
# |LondonMidland  |427996 1025 showing running                                                                                                               |neutral  |
# |427996         |LondonMidland Cmon guys response appreciated  lack information misinformation incredible cancelled                                        |positive |
# |LondonMidland  |427996 responded last tweet 1025 present scheduled run albeit delay                                                                       |negative |
# |427996         |LondonMidland announced Thank                                                                                                             |neutral  |
# |427996         |LondonMidland Currently travelling Milton Keynes Coventry update get                                                                      |neutral  |
# |LondonMidland  |427997 sorry staff give information available time                                                                                        |positive |
# |427997         |LondonMidland 3rd day week trains delayed andor cancelled really                                                                          |negative |
# |427997         |LondonMidland really great job telling people train NUN EUS cancelled got leaving 100s stranded Rugby joke                                |positive |
# |LondonMidland  |427998 train running however cancellations delays 0925 next one                                                                           |negative |
# |427998         |LondonMidland Thank running long buckby Closer                                                                                            |neutral  |
# |427998         |LondonMidland trains running Northampton London                                                                                           |neutral  |
# |LondonMidland  |427999 bridge strike near Rugby may want get Chiltern service Moor st ticket acceptance                                                   |negative |
# |427999         |LondonMidland next train Euston Birmingham New Street everything disorganised                                                             |neutral  |
# |idea_cares     |428000 per telecon issue initiated SR 1146150605606 amp expected completion date 1112017 Heetali                                          |negative |
# |428000         |idea_cares worst response customer care service\nCall immediately otherwise Port number service provider                                  |negative |
# |idea_cares     |428001 Sorry go noted concern team get touch soon Rgds Yogita                                                                             |negative |
# |428001         |116588 116331 \nBad network  lots mess \nSolve issues else Ill change 9917420288                                                          |negative |
# |AskLyft        |428002 Hello please DM AskLyft phone number associated Lyft account httpstcoSXpdictw1A                                                    |neutral  |
# |AirAsiaSupport |428004 Hisorry inconvenience may reprintresend boarding pass httpstcopjTF2ZY1Fz accordingly Thanks  Ed                                    |negative |
# |428004         |AirAsiaSupport u reply msg please                                                                                                         |neutral  |
# |Ask_Spectrum   |428005 Spectrum currently working Viacom reach agreement fair everyone SS                                                                 |positive |
# |428005         |115955 drops Viacom channels final straw httpstcoMtaLEtBbEX                                                                               |neutral  |
# |Ask_Spectrum   |428006 Spectrum currently working Viacom reach agreement fair everyone SS                                                                 |positive |
# |428006         |Spectrum Customers Wont Lose 23 Channels  httpstcowRop004JVz                                                                              |neutral  |
# |Ask_Spectrum   |204205 Good morning Please DM us privately may discuss Thank JLM                                                                          |neutral  |
# |204205         |Ask_Spectrum need possibly get extention one bills guys thanks                                                                            |neutral  |
# |British_Airways|428007 need us rebook flight 22 Linda                                                                                                     |neutral  |
# |428007         |British_Airways \nSorry disturb flight time 1255 LHR BHDBA1416 want know plane take time                                                  |negative |
# |TMobileHelp    |427585 Thats definitely cool want make sure get order placed without delay Please DM JPL                                                  |positive |
# |TMobileHelp    |428008 Hey Ill meet DM thanks httpstcoBMDMqsRi3P DebKlajbor                                                                               |neutral  |
# |428008         |TMobileHelp Cool                                                                                                                          |neutral  |
# |TMobileHelp    |428008 Hey meet DM Im httpstcoBMDMqsRi3P DebKlajbor                                                                                       |neutral  |
# |428008         |First get non US rep try get help issue couldnt understand ask US one rude hung TMobileHelp                                               |negative |
# |TMobileHelp    |428009 Ouch better guys DM us check ElleA                                                                                                 |positive |
# |427754         |TMobileHelp  httpstcoyExyJBCpUj                                                                                                           |neutral  |
# |427754         |TMobileHelp send DM                                                                                                                       |neutral  |
# |TMobileHelp    |428010 Thanks love Sarah TForce always back KyleSaragosa                                                                                  |positive |
# |428010         |TMobileHelp think difference co leadership 115913 knows customer service takes care Amazing imp leadership Thx TM                         |neutral  |
# |428010         |TwitterSupport Co 12 sent customer service team learn TMobileHelp User asks  yall 0 response                                              |neutral  |
# |SouthwestAir   |428011 apologies misunderstanding policy foragainst saving seats LJ                                                                       |negative |
# |428011         |SouthwestAir Well pretty adamant extremely uncomfortable embarrassing guys better                                                         |positive |
# |SouthwestAir   |428011 happened get name flight information youre welcome DM us well share feedback Leaders LJ                                            |positive |
# |428011         |SouthwestAir didnt get name didnt even look eye didnt want confrontation got home safelythats matters                                     |negative |
# |428011         |SouthwestAir rude FA gave heat saving seat hubs Says dont allow EVER 4 people behind board whattt                                         |negative |
# |SouthwestAir   |428012 system doesnt print hyphen boarding pass two separate names without hyphen LJ                                                      |neutral  |
# |428012         |SouthwestAir quit allowing guests hyphenated names print boarding passes 122197                                                           |neutral  |
# |SouthwestAir   |234058 glad welcome onboard morning Rachel LJ                                                                                             |positive |
# |AmazonHelp     |414830 Hi Im glad hear item delivered sorry issue tracking JJ                                                                             |positive |
# |414830         |115821 tracking really wonky lately item told delayed till 7th arrive today                                                               |negative |
# |AmazonHelp     |428013 Sorry hear spoken Supervisor pls let us know issues  TD                                                                            |negative |
# |428013         |AmazonHelp realise yodel part amazon still phone yodel apparently supervisors busy appalling customer service                             |negative |
# |AmazonHelp     |428013 Hi Yodel carrier use certain parcels Please keep us posted matter CR                                                               |neutral  |
# |428013         |127161 driver stole amazon parcel yesterday holding phone trying speak someone supervisor busy                                            |negative |
# |428014         |115825 warum ist da leider nur ein kleiner Bruchteil OV                                                                                   |neutral  |
# |AmazonHelp     |428015 Mi spiace per questo inconveniente Hai ricevuto unemail da parte nostra che ti informava del ritardo ZC                            |neutral  |
# |428015         |AmazonHelp si la cosa che mi fa ridere per  che io posso comprarlo questo momento su prime e riceverlo 2h 12                              |neutral  |
# |AmazonHelp     |428015 Ti suggerisco di inoltrare la tua segnalazione al nostro Servizio Clienti cliccando qui httpstcoyOqfpl3oRN FS                      |neutral  |
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------+---------+
# only showing top 1000 rows

# %% [markdown]
# ### Save to Data Warehouse

# %%
from os.path import abspath

from pyspark.sql import SparkSession
from pyspark.sql import Row

warehouse_location = abspath('spark-warehouse')

spark_hive = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", "hive") \
    .enableHiveSupport() \
    .getOrCreate()

# %% [markdown]
# Create database

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS db_tgp2")
# Out:
# DataFrame[]

# %% [markdown]
# Schema-on-Write

# %%
spark.sql("USE db_tgp2")
spark.sql("CREATE TABLE IF NOT EXISTS customer_tweets (id BIGINT GENERATED ALWAYS AS IDENTITY, author_id STRING, inbound STRING, created_at STRING, text STRING, text_clean STRING, response_tweet_id STRING, in_response_to_tweet_id STRING, sentiment STRING) USING hive")
# Out:
# DataFrame[]

# %% [markdown]
# Write dataframe to Hive Table

# %%
df_twcs_clean.write.mode("overwrite").format("hive").saveAsTable("db_tgp2.customer_tweets")

# %% [markdown]
# Test inserted data

# %%
df = spark.sql("SELECT * FROM customer_tweets LIMIT 1000")
df.show()
# Out:
# +--------------------+--------+-----------+-------+--------------------+--------------------+-----------------+-----------------------+--------------------+--------------------+---------+
# |     timestamp_kafka|tweet_id|  author_id|inbound|          created_at|                text|response_tweet_id|in_response_to_tweet_id|          text_clean|              tokens|sentiment|
# +--------------------+--------+-----------+-------+--------------------+--------------------+-----------------+-----------------------+--------------------+--------------------+---------+
# |2025-06-27 12:57:...| 1317615|TMobileHelp|  false|Fri Oct 27 08:13:...|@427759 What's go...|                 |                1317616|427759 Whats goin...|[Whats, going, Ha...|  neutral|
# |2025-06-27 12:57:...| 1317618|TMobileHelp|  false|Fri Oct 27 08:13:...|@427761 https://t...|                 |                1317619|427761 httpstcoxK...|[httpstcoxKtJVNqc...|  neutral|
# |2025-06-27 12:57:...| 1317621|     427762|   true|Fri Oct 27 08:08:...|@115911 Hi there....|  1317619,1317622|                       |115911 Hi spoke r...|[Hi, spoke, rep, ...|  neutral|
# |2025-06-27 12:57:...| 1317620|TMobileHelp|  false|Fri Oct 27 08:13:...|@427761 If you ca...|                 |                1317619|427761 confirm ac...|[confirm, account...| positive|
# |2025-06-27 12:57:...| 1317623|TMobileHelp|  false|Fri Oct 27 08:13:...|@426997 I see you...|                 |                1317624|426997 see DM res...|[see, DM, respond...|  neutral|
# |2025-06-27 12:57:...| 1317625|TMobileHelp|  false|Fri Oct 27 08:02:...|@426997 We want t...|          1317624|                1317626|426997 want make ...|[want, make, sure...|  neutral|
# |2025-06-27 12:57:...| 1317628|     426998|   true|Fri Oct 27 07:53:...|@426997 nah going...|          1317627|                1317629|426997 nah going ...|[nah, going, stor...|  neutral|
# |2025-06-27 12:57:...| 1317629|     426997|   true|Fri Oct 27 07:52:...|@426998 Why bruh,...|          1317628|                1317630|426998 bruh keep ...|[bruh, keep, trying]|  neutral|
# |2025-06-27 12:57:...| 1317631|     426997|   true|Fri Oct 27 07:47:...|@426998 Got it br...|          1317630|                1317632|426998 Got bro du...|[Got, bro, dunno,...| positive|
# |2025-06-27 12:57:...| 1317632|     426998|   true|Fri Oct 27 07:35:...|@426997 I might h...|          1317631|                1317633|426997 might go s...|[might, go, store...|  neutral|
# |2025-06-27 12:57:...| 1314014|     426998|   true|Fri Oct 27 07:14:...|@426997 @115911 J...|          1317636|                1314013|426997 115911 kee...|      [keep, trying]|  neutral|
# |2025-06-27 12:57:...| 1317637|TMobileHelp|  false|Fri Oct 27 08:13:...|@427763 @115913 T...|                 |                1317638|427763 115913 Tha...|[Thanks, working,...|  neutral|
# |2025-06-27 12:57:...| 1317638|     427763|   true|Fri Oct 27 08:10:...|@115913 I love @1...|          1317637|                       |115913 love 11591...|[love, online, cu...| positive|
# |2025-06-27 12:57:...| 1317639|TMobileHelp|  false|Fri Oct 27 08:13:...|@207219 Anytime A...|                 |                1317640|207219 Anytime An...|[Anytime, Andre, ...|  neutral|
# |2025-06-27 12:57:...| 1317640|     207219|   true|Fri Oct 27 08:07:...|@115911 Thanks, i...|          1317639|                       |115911 Thanks bre...|[Thanks, breeze, ...| positive|
# |2025-06-27 12:57:...| 1317641|TMobileHelp|  false|Fri Oct 27 08:13:...|@427764 Hello! Oh...|                 |                1317642|427764 Hello Oh P...|[Hello, Oh, Pleas...| positive|
# |2025-06-27 12:57:...| 1317643|TMobileHelp|  false|Fri Oct 27 08:13:...|@427765 Thank you...|                 |                1317644|427765 Thank much...|[Thank, much, ama...| positive|
# |2025-06-27 12:57:...| 1317644|     427765|   true|Fri Oct 27 07:51:...|@427766 @115911 N...|          1317643|                1317645|427766 115911 Nei...|[Neither, cost, m...|  neutral|
# |2025-06-27 12:57:...| 1317645|     427766|   true|Fri Oct 27 07:45:...|@427765 @115911 S...|          1317644|                1317646|427765 115911 You...|[Youre, getting, ...|  neutral|
# |2025-06-27 12:57:...| 1317646|     427765|   true|Fri Oct 27 07:44:...|Thanks @115911 ht...|          1317645|                       |Thanks 115911 htt...|[Thanks, httpstco...|  neutral|
# +--------------------+--------+-----------+-------+--------------------+--------------------+-----------------+-----------------------+--------------------+--------------------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Save cleaned data to Data Lake

# %%
df_twcs_clean.write.mode("overwrite").format("parquet").save("hdfs://localhost:9000/hdfs_twcs_clean")

# %%
df2 = spark.read.parquet("hdfs://localhost:9000/hdfs_twcs_clean")
df2.show(10, truncate=False)
# Out:
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+---------+
# |timestamp_kafka        |tweet_id|author_id  |inbound|created_at                    |text                                                                                                                                 |response_tweet_id|in_response_to_tweet_id|text_clean                                                                      |tokens                                                                                |sentiment|
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+---------+
# |2025-06-27 12:57:26.818|1317615 |TMobileHelp|false  |Fri Oct 27 08:13:27 +0000 2017|@427759 What's going on, Hadas? *NaeJ                                                                                                |                 |1317616                |427759 Whats going Hadas NaeJ                                                   |[Whats, going, Hadas, NaeJ]                                                           |neutral  |
# |2025-06-27 12:57:26.818|1317618 |TMobileHelp|false  |Fri Oct 27 08:13:25 +0000 2017|@427761 https://t.co/xKtJVNqc2V *RileyRed                                                                                            |                 |1317619                |427761 httpstcoxKtJVNqc2V RileyRed                                              |[httpstcoxKtJVNqc2V, RileyRed]                                                        |neutral  |
# |2025-06-27 12:57:26.818|1317621 |427762     |true   |Fri Oct 27 08:08:53 +0000 2017|@115911 Hi there. I spoke with a rep to place an iPhone X order but have not received any sort of confirmation email. Is that normal?|1317619,1317622  |                       |115911 Hi spoke rep place iPhone X order received sort confirmation email normal|[Hi, spoke, rep, place, iPhone, X, order, received, sort, confirmation, email, normal]|neutral  |
# |2025-06-27 12:57:26.818|1317620 |TMobileHelp|false  |Fri Oct 27 08:13:21 +0000 2017|@427761 If you can confirm your account for me I can jump right in! *RileyRed                                                        |                 |1317619                |427761 confirm account jump right RileyRed                                      |[confirm, account, jump, right, RileyRed]                                             |positive |
# |2025-06-27 12:57:26.818|1317623 |TMobileHelp|false  |Fri Oct 27 08:13:19 +0000 2017|@426997 I see your DM and will be responding shortly. Thanks for hanging in there with us. *JeromyBingham                            |                 |1317624                |426997 see DM responding shortly Thanks hanging us JeromyBingham                |[see, DM, responding, shortly, Thanks, hanging, us, JeromyBingham]                    |neutral  |
# |2025-06-27 12:57:26.818|1317625 |TMobileHelp|false  |Fri Oct 27 08:02:48 +0000 2017|@426997 We want to make sure you have all the information about your order. Let's take a look, send us a DM. *JeromyBingham          |1317624          |1317626                |426997 want make sure information order Lets take look send us DM JeromyBingham |[want, make, sure, information, order, Lets, take, look, send, us, DM, JeromyBingham] |neutral  |
# |2025-06-27 12:57:26.819|1317628 |426998     |true   |Fri Oct 27 07:53:52 +0000 2017|@426997 nah going to store I need it on the 3rd                                                                                      |1317627          |1317629                |426997 nah going store need 3rd                                                 |[nah, going, store, need, 3rd]                                                        |neutral  |
# |2025-06-27 12:57:26.819|1317629 |426997     |true   |Fri Oct 27 07:52:10 +0000 2017|@426998 Why bruh, keep trying                                                                                                        |1317628          |1317630                |426998 bruh keep trying                                                         |[bruh, keep, trying]                                                                  |neutral  |
# |2025-06-27 12:57:26.819|1317631 |426997     |true   |Fri Oct 27 07:47:19 +0000 2017|@426998 Got it bro, I dunno if I should go back to sleep or just wait and go to work early lol                                       |1317630          |1317632                |426998 Got bro dunno go back sleep wait go work early lol                       |[Got, bro, dunno, go, back, sleep, wait, go, work, early, lol]                        |positive |
# |2025-06-27 12:57:26.819|1317632 |426998     |true   |Fri Oct 27 07:35:06 +0000 2017|@426997 I might have to go to the store early to get one                                                                             |1317631          |1317633                |426997 might go store early get one                                             |[might, go, store, early, get, one]                                                   |neutral  |
# +-----------------------+--------+-----------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+---------+
# only showing top 10 rows
