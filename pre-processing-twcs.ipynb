# %% [markdown]
# ### Connect spark and deltalake

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("DeltaLake with Hive Integration") \
    .master("local[*]") \
    .config("spark.jars.packages", 
            "org.apache.spark:spark-sql-kafka-0-10_2.13:4.0.0,io.delta:delta-spark_2.13:4.0.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.sql.warehouse.dir", "file:///C:/Uni_Master/Project/tgp-mdik-2/hive/") \
    .config("spark.hadoop.javax.jdo.option.ConnectionURL", "jdbc:derby:;databaseName=metastore_db;create=true") \
    .config("spark.hadoop.javax.jdo.option.ConnectionDriverName", "org.apache.derby.jdbc.EmbeddedDriver") \
    .config("spark.python.worker.timeout", "1200") \
    .config("spark.network.timeout", "1200s") \
    .config("spark.executor.heartbeatInterval", "60s") \
    .config("spark.python.worker.reuse", "true") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "false") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .enableHiveSupport() \
    .getOrCreate()

df_twcs = spark.read.format("delta").load("hdfs://localhost:9000/delta_twcs")
print(df_twcs)
# Out:
# DataFrame[message: string, timestamp_kafka: timestamp]

# %% [markdown]
# ### Preprocessing tweets data

# %%
import pandas as pd 
import numpy as np 
import json

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import StopWordsRemover

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# Map delta format data to dataframe

# %%
df_parsed = df_twcs.select(
    col("timestamp_kafka"),
    from_json(
        col("message"),
        "tweet_id string, author_id string, inbound string, created_at string, text string, response_tweet_id string, in_response_to_tweet_id string"
    ).alias("data"))


df_column = df_parsed.select(
    col("timestamp_kafka"),
    col("data.tweet_id").alias("tweet_id"),
    col("data.author_id").alias("author_id"),
    (col("data.inbound") == "True").alias("inbound"),
    col("data.created_at").alias("created_at"),
    col("data.text").alias("text"),
    col("data.response_tweet_id").alias("response_tweet_id"),
    col("data.in_response_to_tweet_id").alias("in_response_to_tweet_id")
).filter(col("tweet_id").isNotNull())

# %%
df_parsed.show(10, truncate=False)
df_column.show(10, truncate=False)
df_parsed.printSchema()
# Out:
# +-----------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |data                                                                                                                                                                                                                                                                                                                                   |
# +-----------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-26 15:54:19.72 |{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                                                                                                                                             |
# |2025-06-26 15:54:19.72 |{2555292, AppleSupport, False, Thu Nov 16 16:05:35 +0000 2017, @246955 Thanks for contacting us. We can understand how important it is to have your alarms working properly. Are you able to re-add the alarm without issue?, 2555293, 2555294}                                                                                        |
# |2025-06-26 15:54:19.72 |{2555293, 246955, True, Thu Nov 16 19:28:52 +0000 2017, @AppleSupport Yes I added it back, 2555295, 2555292}                                                                                                                                                                                                                           |
# |2025-06-26 15:54:19.72 |{2555295, AppleSupport, False, Thu Nov 16 20:46:00 +0000 2017, @246955 Let's keep an eye on it and see if the issue comes back. If it does, let us know. Also, if you haven't already done so, we'd recommend making sure the iOS is updated. Please be sure to back up prior to updating: https://t.co/80YRnjVguS, , 2555293}         |
# |2025-06-26 15:54:19.72 |{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                                                                                                                                             |
# |2025-06-26 15:54:19.72 |{2555296, AppleSupport, False, Thu Nov 16 16:05:35 +0000 2017, @725612 We'd be happy to assist with your music today. Send us a DM to get started. https://t.co/GDrqU22YpT, , 2555297}                                                                                                                                                 |
# |2025-06-26 15:54:19.721|{2555297, 725612, True, Thu Nov 16 13:37:56 +0000 2017, @AppleSupport hi. Why is my music coming up like this. I've downloaded it already https://t.co/brZgMhddnt, 2555296, }                                                                                                                                                          |
# |2025-06-26 15:54:19.721|{NULL, NULL, NULL, NULL, NULL, NULL, NULL}                                                                                                                                                                                                                                                                                             |
# |2025-06-26 15:54:19.721|{2555299, 725613, True, Thu Nov 16 13:48:01 +0000 2017, @115858 #ios11.1.1Bug is killing all the #iPhoneSE versions. After the update, iphones which were normally working were started being frozen and stuck with  an #appleLogo on a black screen and started the restart game. Apple a fix please. @99089 @99088 Still?, 2555298, }|
# |2025-06-26 15:54:19.721|{2555300, AppleSupport, False, Thu Nov 16 16:04:03 +0000 2017, @725614 Let's take a look at this together. When you restore, are you using iTunes or are you erasing your iPhone from the Settings? Let us know in DM and we'll team up to get this resolved. https://t.co/GDrqU22YpT, , 2555301}                                      |
# +-----------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+
# |timestamp_kafka        |tweet_id|author_id   |inbound|created_at                    |text                                                                                                                                                                                                                                                               |response_tweet_id|in_response_to_tweet_id|
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+
# |2025-06-26 15:54:19.72 |2555292 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@246955 Thanks for contacting us. We can understand how important it is to have your alarms working properly. Are you able to re-add the alarm without issue?                                                                                                      |2555293          |2555294                |
# |2025-06-26 15:54:19.72 |2555293 |246955      |true   |Thu Nov 16 19:28:52 +0000 2017|@AppleSupport Yes I added it back                                                                                                                                                                                                                                  |2555295          |2555292                |
# |2025-06-26 15:54:19.72 |2555295 |AppleSupport|false  |Thu Nov 16 20:46:00 +0000 2017|@246955 Let's keep an eye on it and see if the issue comes back. If it does, let us know. Also, if you haven't already done so, we'd recommend making sure the iOS is updated. Please be sure to back up prior to updating: https://t.co/80YRnjVguS                |                 |2555293                |
# |2025-06-26 15:54:19.72 |2555296 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@725612 We'd be happy to assist with your music today. Send us a DM to get started. https://t.co/GDrqU22YpT                                                                                                                                                        |                 |2555297                |
# |2025-06-26 15:54:19.721|2555297 |725612      |true   |Thu Nov 16 13:37:56 +0000 2017|@AppleSupport hi. Why is my music coming up like this. I've downloaded it already https://t.co/brZgMhddnt                                                                                                                                                          |2555296          |                       |
# |2025-06-26 15:54:19.721|2555299 |725613      |true   |Thu Nov 16 13:48:01 +0000 2017|@115858 #ios11.1.1Bug is killing all the #iPhoneSE versions. After the update, iphones which were normally working were started being frozen and stuck with  an #appleLogo on a black screen and started the restart game. Apple a fix please. @99089 @99088 Still?|2555298          |                       |
# |2025-06-26 15:54:19.721|2555300 |AppleSupport|false  |Thu Nov 16 16:04:03 +0000 2017|@725614 Let's take a look at this together. When you restore, are you using iTunes or are you erasing your iPhone from the Settings? Let us know in DM and we'll team up to get this resolved. https://t.co/GDrqU22YpT                                             |                 |2555301                |
# |2025-06-26 15:54:19.721|2555301 |725614      |true   |Thu Nov 16 14:01:05 +0000 2017|@AppleSupport when will you realize your stupid update problem that makes me restore my iPhone daily?                                                                                                                                                              |2555300          |                       |
# |2025-06-26 15:54:19.721|2555302 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725615 That certainly isn't expected and we would love to help take a look at this. Go ahead and reach out to us in DM and tell us more about what's going on. We will definitely help get on a path to getting this resolved. https://t.co/GDrqU22YpT            |                 |2555303                |
# |2025-06-26 15:54:19.721|2555304 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725616 Thanks for contacting us. We'd like to gather some info on what is happening with your device. Let's meet in DM. https://t.co/GDrqU22YpT                                                                                                                   |                 |2555305                |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+
# only showing top 10 rows
# root
#  |-- timestamp_kafka: timestamp (nullable = true)
#  |-- data: struct (nullable = true)
#  |    |-- tweet_id: string (nullable = true)
#  |    |-- author_id: string (nullable = true)
#  |    |-- inbound: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- response_tweet_id: string (nullable = true)
#  |    |-- in_response_to_tweet_id: string (nullable = true)

# %% [markdown]
# Convert to lowercase

# %%
df_twcs_clean = df_column.withColumn("text_clean", lower(col("text")))
df_twcs_clean.show(10, truncate=False)
# Out:
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |tweet_id|author_id   |inbound|created_at                    |text                                                                                                                                                                                                                                                               |response_tweet_id|in_response_to_tweet_id|text_clean                                                                                                                                                                                                                                                         |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-26 15:54:19.72 |2555292 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@246955 Thanks for contacting us. We can understand how important it is to have your alarms working properly. Are you able to re-add the alarm without issue?                                                                                                      |2555293          |2555294                |@246955 thanks for contacting us. we can understand how important it is to have your alarms working properly. are you able to re-add the alarm without issue?                                                                                                      |
# |2025-06-26 15:54:19.72 |2555293 |246955      |true   |Thu Nov 16 19:28:52 +0000 2017|@AppleSupport Yes I added it back                                                                                                                                                                                                                                  |2555295          |2555292                |@applesupport yes i added it back                                                                                                                                                                                                                                  |
# |2025-06-26 15:54:19.72 |2555295 |AppleSupport|false  |Thu Nov 16 20:46:00 +0000 2017|@246955 Let's keep an eye on it and see if the issue comes back. If it does, let us know. Also, if you haven't already done so, we'd recommend making sure the iOS is updated. Please be sure to back up prior to updating: https://t.co/80YRnjVguS                |                 |2555293                |@246955 let's keep an eye on it and see if the issue comes back. if it does, let us know. also, if you haven't already done so, we'd recommend making sure the ios is updated. please be sure to back up prior to updating: https://t.co/80yrnjvgus                |
# |2025-06-26 15:54:19.72 |2555296 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@725612 We'd be happy to assist with your music today. Send us a DM to get started. https://t.co/GDrqU22YpT                                                                                                                                                        |                 |2555297                |@725612 we'd be happy to assist with your music today. send us a dm to get started. https://t.co/gdrqu22ypt                                                                                                                                                        |
# |2025-06-26 15:54:19.721|2555297 |725612      |true   |Thu Nov 16 13:37:56 +0000 2017|@AppleSupport hi. Why is my music coming up like this. I've downloaded it already https://t.co/brZgMhddnt                                                                                                                                                          |2555296          |                       |@applesupport hi. why is my music coming up like this. i've downloaded it already https://t.co/brzgmhddnt                                                                                                                                                          |
# |2025-06-26 15:54:19.721|2555299 |725613      |true   |Thu Nov 16 13:48:01 +0000 2017|@115858 #ios11.1.1Bug is killing all the #iPhoneSE versions. After the update, iphones which were normally working were started being frozen and stuck with  an #appleLogo on a black screen and started the restart game. Apple a fix please. @99089 @99088 Still?|2555298          |                       |@115858 #ios11.1.1bug is killing all the #iphonese versions. after the update, iphones which were normally working were started being frozen and stuck with  an #applelogo on a black screen and started the restart game. apple a fix please. @99089 @99088 still?|
# |2025-06-26 15:54:19.721|2555300 |AppleSupport|false  |Thu Nov 16 16:04:03 +0000 2017|@725614 Let's take a look at this together. When you restore, are you using iTunes or are you erasing your iPhone from the Settings? Let us know in DM and we'll team up to get this resolved. https://t.co/GDrqU22YpT                                             |                 |2555301                |@725614 let's take a look at this together. when you restore, are you using itunes or are you erasing your iphone from the settings? let us know in dm and we'll team up to get this resolved. https://t.co/gdrqu22ypt                                             |
# |2025-06-26 15:54:19.721|2555301 |725614      |true   |Thu Nov 16 14:01:05 +0000 2017|@AppleSupport when will you realize your stupid update problem that makes me restore my iPhone daily?                                                                                                                                                              |2555300          |                       |@applesupport when will you realize your stupid update problem that makes me restore my iphone daily?                                                                                                                                                              |
# |2025-06-26 15:54:19.721|2555302 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725615 That certainly isn't expected and we would love to help take a look at this. Go ahead and reach out to us in DM and tell us more about what's going on. We will definitely help get on a path to getting this resolved. https://t.co/GDrqU22YpT            |                 |2555303                |@725615 that certainly isn't expected and we would love to help take a look at this. go ahead and reach out to us in dm and tell us more about what's going on. we will definitely help get on a path to getting this resolved. https://t.co/gdrqu22ypt            |
# |2025-06-26 15:54:19.721|2555304 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725616 Thanks for contacting us. We'd like to gather some info on what is happening with your device. Let's meet in DM. https://t.co/GDrqU22YpT                                                                                                                   |                 |2555305                |@725616 thanks for contacting us. we'd like to gather some info on what is happening with your device. let's meet in dm. https://t.co/gdrqu22ypt                                                                                                                   |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Remove punctuation

# %%
df_twcs_clean = df_twcs_clean.withColumn(
    "text_clean", regexp_replace(col("text"), r"[^\w\s]", "")
)

df_twcs_clean.show(10, truncate=False)
# Out:
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |tweet_id|author_id   |inbound|created_at                    |text                                                                                                                                                                                                                                                               |response_tweet_id|in_response_to_tweet_id|text_clean                                                                                                                                                                                                                                            |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-26 15:54:19.72 |2555292 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@246955 Thanks for contacting us. We can understand how important it is to have your alarms working properly. Are you able to re-add the alarm without issue?                                                                                                      |2555293          |2555294                |246955 Thanks for contacting us We can understand how important it is to have your alarms working properly Are you able to readd the alarm without issue                                                                                              |
# |2025-06-26 15:54:19.72 |2555293 |246955      |true   |Thu Nov 16 19:28:52 +0000 2017|@AppleSupport Yes I added it back                                                                                                                                                                                                                                  |2555295          |2555292                |AppleSupport Yes I added it back                                                                                                                                                                                                                      |
# |2025-06-26 15:54:19.72 |2555295 |AppleSupport|false  |Thu Nov 16 20:46:00 +0000 2017|@246955 Let's keep an eye on it and see if the issue comes back. If it does, let us know. Also, if you haven't already done so, we'd recommend making sure the iOS is updated. Please be sure to back up prior to updating: https://t.co/80YRnjVguS                |                 |2555293                |246955 Lets keep an eye on it and see if the issue comes back If it does let us know Also if you havent already done so wed recommend making sure the iOS is updated Please be sure to back up prior to updating httpstco80YRnjVguS                   |
# |2025-06-26 15:54:19.72 |2555296 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@725612 We'd be happy to assist with your music today. Send us a DM to get started. https://t.co/GDrqU22YpT                                                                                                                                                        |                 |2555297                |725612 Wed be happy to assist with your music today Send us a DM to get started httpstcoGDrqU22YpT                                                                                                                                                    |
# |2025-06-26 15:54:19.721|2555297 |725612      |true   |Thu Nov 16 13:37:56 +0000 2017|@AppleSupport hi. Why is my music coming up like this. I've downloaded it already https://t.co/brZgMhddnt                                                                                                                                                          |2555296          |                       |AppleSupport hi Why is my music coming up like this Ive downloaded it already httpstcobrZgMhddnt                                                                                                                                                      |
# |2025-06-26 15:54:19.721|2555299 |725613      |true   |Thu Nov 16 13:48:01 +0000 2017|@115858 #ios11.1.1Bug is killing all the #iPhoneSE versions. After the update, iphones which were normally working were started being frozen and stuck with  an #appleLogo on a black screen and started the restart game. Apple a fix please. @99089 @99088 Still?|2555298          |                       |115858 ios1111Bug is killing all the iPhoneSE versions After the update iphones which were normally working were started being frozen and stuck with  an appleLogo on a black screen and started the restart game Apple a fix please 99089 99088 Still|
# |2025-06-26 15:54:19.721|2555300 |AppleSupport|false  |Thu Nov 16 16:04:03 +0000 2017|@725614 Let's take a look at this together. When you restore, are you using iTunes or are you erasing your iPhone from the Settings? Let us know in DM and we'll team up to get this resolved. https://t.co/GDrqU22YpT                                             |                 |2555301                |725614 Lets take a look at this together When you restore are you using iTunes or are you erasing your iPhone from the Settings Let us know in DM and well team up to get this resolved httpstcoGDrqU22YpT                                            |
# |2025-06-26 15:54:19.721|2555301 |725614      |true   |Thu Nov 16 14:01:05 +0000 2017|@AppleSupport when will you realize your stupid update problem that makes me restore my iPhone daily?                                                                                                                                                              |2555300          |                       |AppleSupport when will you realize your stupid update problem that makes me restore my iPhone daily                                                                                                                                                   |
# |2025-06-26 15:54:19.721|2555302 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725615 That certainly isn't expected and we would love to help take a look at this. Go ahead and reach out to us in DM and tell us more about what's going on. We will definitely help get on a path to getting this resolved. https://t.co/GDrqU22YpT            |                 |2555303                |725615 That certainly isnt expected and we would love to help take a look at this Go ahead and reach out to us in DM and tell us more about whats going on We will definitely help get on a path to getting this resolved httpstcoGDrqU22YpT          |
# |2025-06-26 15:54:19.721|2555304 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725616 Thanks for contacting us. We'd like to gather some info on what is happening with your device. Let's meet in DM. https://t.co/GDrqU22YpT                                                                                                                   |                 |2555305                |725616 Thanks for contacting us Wed like to gather some info on what is happening with your device Lets meet in DM httpstcoGDrqU22YpT                                                                                                                 |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Remove stopwords

# %%
stop_words_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")

df_twcs_clean = df_twcs_clean.withColumn("words", split(col("text_clean"), " ")) \
                  .transform(stop_words_remover.transform) \
                  .withColumn("text_clean", concat_ws(" ", col("filtered_words"))) \
                  .drop("words", "filtered_words")

# %%
df_twcs_clean.show(10, truncate=False)
# Out:
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp_kafka        |tweet_id|author_id   |inbound|created_at                    |text                                                                                                                                                                                                                                                               |response_tweet_id|in_response_to_tweet_id|text_clean                                                                                                                                                                      |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2025-06-26 15:54:19.72 |2555292 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@246955 Thanks for contacting us. We can understand how important it is to have your alarms working properly. Are you able to re-add the alarm without issue?                                                                                                      |2555293          |2555294                |246955 Thanks contacting us understand important alarms working properly able readd alarm without issue                                                                         |
# |2025-06-26 15:54:19.72 |2555293 |246955      |true   |Thu Nov 16 19:28:52 +0000 2017|@AppleSupport Yes I added it back                                                                                                                                                                                                                                  |2555295          |2555292                |AppleSupport Yes added back                                                                                                                                                     |
# |2025-06-26 15:54:19.72 |2555295 |AppleSupport|false  |Thu Nov 16 20:46:00 +0000 2017|@246955 Let's keep an eye on it and see if the issue comes back. If it does, let us know. Also, if you haven't already done so, we'd recommend making sure the iOS is updated. Please be sure to back up prior to updating: https://t.co/80YRnjVguS                |                 |2555293                |246955 Lets keep eye see issue comes back let us know Also havent already done wed recommend making sure iOS updated Please sure back prior updating httpstco80YRnjVguS         |
# |2025-06-26 15:54:19.72 |2555296 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@725612 We'd be happy to assist with your music today. Send us a DM to get started. https://t.co/GDrqU22YpT                                                                                                                                                        |                 |2555297                |725612 Wed happy assist music today Send us DM get started httpstcoGDrqU22YpT                                                                                                   |
# |2025-06-26 15:54:19.721|2555297 |725612      |true   |Thu Nov 16 13:37:56 +0000 2017|@AppleSupport hi. Why is my music coming up like this. I've downloaded it already https://t.co/brZgMhddnt                                                                                                                                                          |2555296          |                       |AppleSupport hi music coming like Ive downloaded already httpstcobrZgMhddnt                                                                                                     |
# |2025-06-26 15:54:19.721|2555299 |725613      |true   |Thu Nov 16 13:48:01 +0000 2017|@115858 #ios11.1.1Bug is killing all the #iPhoneSE versions. After the update, iphones which were normally working were started being frozen and stuck with  an #appleLogo on a black screen and started the restart game. Apple a fix please. @99089 @99088 Still?|2555298          |                       |115858 ios1111Bug killing iPhoneSE versions update iphones normally working started frozen stuck  appleLogo black screen started restart game Apple fix please 99089 99088 Still|
# |2025-06-26 15:54:19.721|2555300 |AppleSupport|false  |Thu Nov 16 16:04:03 +0000 2017|@725614 Let's take a look at this together. When you restore, are you using iTunes or are you erasing your iPhone from the Settings? Let us know in DM and we'll team up to get this resolved. https://t.co/GDrqU22YpT                                             |                 |2555301                |725614 Lets take look together restore using iTunes erasing iPhone Settings Let us know DM well team get resolved httpstcoGDrqU22YpT                                            |
# |2025-06-26 15:54:19.721|2555301 |725614      |true   |Thu Nov 16 14:01:05 +0000 2017|@AppleSupport when will you realize your stupid update problem that makes me restore my iPhone daily?                                                                                                                                                              |2555300          |                       |AppleSupport realize stupid update problem makes restore iPhone daily                                                                                                           |
# |2025-06-26 15:54:19.721|2555302 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725615 That certainly isn't expected and we would love to help take a look at this. Go ahead and reach out to us in DM and tell us more about what's going on. We will definitely help get on a path to getting this resolved. https://t.co/GDrqU22YpT            |                 |2555303                |725615 certainly isnt expected love help take look Go ahead reach us DM tell us whats going definitely help get path getting resolved httpstcoGDrqU22YpT                        |
# |2025-06-26 15:54:19.721|2555304 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725616 Thanks for contacting us. We'd like to gather some info on what is happening with your device. Let's meet in DM. https://t.co/GDrqU22YpT                                                                                                                   |                 |2555305                |725616 Thanks contacting us Wed like gather info happening device Lets meet DM httpstcoGDrqU22YpT                                                                               |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# Tokenization

# %%
df_twcs_clean = df_twcs_clean.withColumn(
    "tokens", 
    expr("filter(split(text_clean, ' '), x -> NOT x RLIKE '^[0-9]+$')")
)

df_twcs_clean.select("text_clean", "tokens").show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text_clean                                                                                                                                                                      |tokens                                                                                                                                                                                     |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |246955 Thanks contacting us understand important alarms working properly able readd alarm without issue                                                                         |[Thanks, contacting, us, understand, important, alarms, working, properly, able, readd, alarm, without, issue]                                                                             |
# |AppleSupport Yes added back                                                                                                                                                     |[AppleSupport, Yes, added, back]                                                                                                                                                           |
# |246955 Lets keep eye see issue comes back let us know Also havent already done wed recommend making sure iOS updated Please sure back prior updating httpstco80YRnjVguS         |[Lets, keep, eye, see, issue, comes, back, let, us, know, Also, havent, already, done, wed, recommend, making, sure, iOS, updated, Please, sure, back, prior, updating, httpstco80YRnjVguS]|
# |725612 Wed happy assist music today Send us DM get started httpstcoGDrqU22YpT                                                                                                   |[Wed, happy, assist, music, today, Send, us, DM, get, started, httpstcoGDrqU22YpT]                                                                                                         |
# |AppleSupport hi music coming like Ive downloaded already httpstcobrZgMhddnt                                                                                                     |[AppleSupport, hi, music, coming, like, Ive, downloaded, already, httpstcobrZgMhddnt]                                                                                                      |
# |115858 ios1111Bug killing iPhoneSE versions update iphones normally working started frozen stuck  appleLogo black screen started restart game Apple fix please 99089 99088 Still|[ios1111Bug, killing, iPhoneSE, versions, update, iphones, normally, working, started, frozen, stuck, , appleLogo, black, screen, started, restart, game, Apple, fix, please, Still]       |
# |725614 Lets take look together restore using iTunes erasing iPhone Settings Let us know DM well team get resolved httpstcoGDrqU22YpT                                            |[Lets, take, look, together, restore, using, iTunes, erasing, iPhone, Settings, Let, us, know, DM, well, team, get, resolved, httpstcoGDrqU22YpT]                                          |
# |AppleSupport realize stupid update problem makes restore iPhone daily                                                                                                           |[AppleSupport, realize, stupid, update, problem, makes, restore, iPhone, daily]                                                                                                            |
# |725615 certainly isnt expected love help take look Go ahead reach us DM tell us whats going definitely help get path getting resolved httpstcoGDrqU22YpT                        |[certainly, isnt, expected, love, help, take, look, Go, ahead, reach, us, DM, tell, us, whats, going, definitely, help, get, path, getting, resolved, httpstcoGDrqU22YpT]                  |
# |725616 Thanks contacting us Wed like gather info happening device Lets meet DM httpstcoGDrqU22YpT                                                                               |[Thanks, contacting, us, Wed, like, gather, info, happening, device, Lets, meet, DM, httpstcoGDrqU22YpT]                                                                                   |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
df_twcs_clean.select("text_clean").show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text_clean                                                                                                                                                                      |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |246955 Thanks contacting us understand important alarms working properly able readd alarm without issue                                                                         |
# |AppleSupport Yes added back                                                                                                                                                     |
# |246955 Lets keep eye see issue comes back let us know Also havent already done wed recommend making sure iOS updated Please sure back prior updating httpstco80YRnjVguS         |
# |725612 Wed happy assist music today Send us DM get started httpstcoGDrqU22YpT                                                                                                   |
# |AppleSupport hi music coming like Ive downloaded already httpstcobrZgMhddnt                                                                                                     |
# |115858 ios1111Bug killing iPhoneSE versions update iphones normally working started frozen stuck  appleLogo black screen started restart game Apple fix please 99089 99088 Still|
# |725614 Lets take look together restore using iTunes erasing iPhone Settings Let us know DM well team get resolved httpstcoGDrqU22YpT                                            |
# |AppleSupport realize stupid update problem makes restore iPhone daily                                                                                                           |
# |725615 certainly isnt expected love help take look Go ahead reach us DM tell us whats going definitely help get path getting resolved httpstcoGDrqU22YpT                        |
# |725616 Thanks contacting us Wed like gather info happening device Lets meet DM httpstcoGDrqU22YpT                                                                               |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# Create label

# %%
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon
# Out:
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\mrifq\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %%
positive_keywords = list(opinion_lexicon.positive())
negative_list = list(opinion_lexicon.negative())
custom_negative = ["sucks", "bad", "hate", "worst", "terrible", "awful", "disappointing", "fuck", "shit"]
negative_keywords = negative_list + custom_negative

df_twcs_clean = df_twcs_clean.withColumn(
    "sentiment",
    when(
        size(array_intersect(col("tokens"), array([lit(x) for x in positive_keywords]))) > 0, "positive"
    ).when(
        size(array_intersect(col("tokens"), array([lit(x) for x in negative_keywords]))) > 0, "negative"
    ).otherwise("neutral")
)

# %%
df_twcs_clean.select("author_id","text_clean", "sentiment").show(1000, truncate=False)
# Out:
# +---------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |author_id      |text_clean                                                                                                                                                                                                                  |sentiment|
# +---------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |AppleSupport   |246955 Thanks contacting us understand important alarms working properly able readd alarm without issue                                                                                                                     |positive |
# |246955         |AppleSupport Yes added back                                                                                                                                                                                                 |neutral  |
# |AppleSupport   |246955 Lets keep eye see issue comes back let us know Also havent already done wed recommend making sure iOS updated Please sure back prior updating httpstco80YRnjVguS                                                     |positive |
# |AppleSupport   |725612 Wed happy assist music today Send us DM get started httpstcoGDrqU22YpT                                                                                                                                               |positive |
# |725612         |AppleSupport hi music coming like Ive downloaded already httpstcobrZgMhddnt                                                                                                                                                 |positive |
# |725613         |115858 ios1111Bug killing iPhoneSE versions update iphones normally working started frozen stuck  appleLogo black screen started restart game Apple fix please 99089 99088 Still                                            |negative |
# |AppleSupport   |725614 Lets take look together restore using iTunes erasing iPhone Settings Let us know DM well team get resolved httpstcoGDrqU22YpT                                                                                        |positive |
# |725614         |AppleSupport realize stupid update problem makes restore iPhone daily                                                                                                                                                       |negative |
# |AppleSupport   |725615 certainly isnt expected love help take look Go ahead reach us DM tell us whats going definitely help get path getting resolved httpstcoGDrqU22YpT                                                                    |positive |
# |AppleSupport   |725616 Thanks contacting us Wed like gather info happening device Lets meet DM httpstcoGDrqU22YpT                                                                                                                           |positive |
# |725616         |AppleSupport iPhone 6s fucking useless latest iOS update Thanks                                                                                                                                                             |negative |
# |725617         |Hi AppleSupport want iPhone X question first help                                                                                                                                                                           |neutral  |
# |AppleSupport   |725618 Well much help updated iOS 1111 yet httpstco80YRnjDFDk apps updated App Store                                                                                                                                        |neutral  |
# |AppleSupport   |725619 Lets join together take look issues experiencing Also updated iOS 1111                                                                                                                                               |negative |
# |725619         |AppleSupport Yes iPhone issues loading safari WiFi WiFi signal weaker update Several apps run much slower work updated yesterday                                                                                            |positive |
# |AppleSupport   |725619 Thanks information Please join us DM well continue httpstcoGDrqU22YpT                                                                                                                                                |positive |
# |725619         |iOS update rendered phone nearly useless Pls fix AppleSupport                                                                                                                                                               |negative |
# |AppleSupport   |725620 Thanks clarifying us update characters wont show posts anymore youll continue see others posts messages                                                                                                              |neutral  |
# |725620         |STILL SEE BOXES UPDATED PHONE 115858                                                                                                                                                                                        |neutral  |
# |AppleSupport   |725621 help device using iOS version currently                                                                                                                                                                              |neutral  |
# |AppleSupport   |725621 notice certain applications tasks run slower since updating iOS 1111  Let us know DM httpstcoGDrqU22YpT                                                                                                              |negative |
# |AppleSupport   |725622 Well happy assist looking towards getting resolved getting specific error message sort                                                                                                                               |positive |
# |AppleSupport   |725622 Okay lets work together DM httpstcoGDrqU22YpT                                                                                                                                                                        |positive |
# |725622         |fucking update ruined iMessages im mad af AppleSupport                                                                                                                                                                      |negative |
# |AppleSupport   |682280 Well take look device encountering issue                                                                                                                                                                             |negative |
# |682280         |AppleSupport iPhone 7                                                                                                                                                                                                       |neutral  |
# |AppleSupport   |682280 Lets try isolate little swapping cords see issue aux cord iPhone different aux cord try able hear music earphones                                                                                                    |negative |
# |AppleSupport   |682280 understand issue\n friend using different aux cord iPhone car\n referring cord connects Lightning Audio Adapter connects Aux port car direct connection                                                              |neutral  |
# |682280         |AppleSupport Yes friend using different one aux cord adaptor Apple working fine updated phone                                                                                                                               |positive |
# |AppleSupport   |682280 Lets look Send us DM well go httpstcoGDrqU22YpT                                                                                                                                                                      |positive |
# |AppleSupport   |725623 help version iOS experiencing Find Settings gt General gt reply DM httpstcoGDrqU22YpT                                                                                                                                |neutral  |
# |AppleSupport   |725624 Thanks reaching us Wed like help get contact Apple Online Store Support help Check link contact httpstco8yjRd1Xo0i                                                                                                   |positive |
# |725624         |147613 lost iPhoneX support called numbers unprofessional angry 115858 right using service 81 115817 \nsupport CustomerService delivery angry sad IphoneXPreOrder  PM help                                                  |positive |
# |AppleSupport   |725625 know important working device iPhone model iOS version installed Let us know DM well continue httpstcoGDrqU22YpT                                                                                                     |positive |
# |725625         |AppleSupport updated phone battery life shocking Remedy                                                                                                                                                                     |negative |
# |AppleSupport   |725626 Thank taking time reach us want look software version using Also first notice                                                                                                                                        |neutral  |
# |725626         |AppleSupport 1103 got Apple Music days Around month ago                                                                                                                                                                     |neutral  |
# |AppleSupport   |725626 First thing get updated current version iOS updates many fixes within may resolved simply updating                                                                                                                   |neutral  |
# |725626         |AppleSupport Apple Music timer songs lags even though song streams perfectly fine ie Time stops Also lags bit skip song                                                                                                     |positive |
# |AppleSupport   |725627 Well happy assist best tried getting recovery mode yet heres httpstcodwZ2UVMxdg                                                                                                                                      |positive |
# |725627         |AppleSupport OS reinstalling thanks million                                                                                                                                                                                 |neutral  |
# |AppleSupport   |725627 glad hear Let us know theres anything else assist                                                                                                                                                                    |positive |
# |725627         |AppleSupport please help left Mac installing new OS update came back found switched happened httpstcoHrJMKdVIJv                                                                                                             |neutral  |
# |AppleSupport   |725628 Wed happy dig whats causing autocorrect issue youre seeing mention happening Mac happening type letter seeing issue viewing content others typed                                                                     |positive |
# |725628         |AppleSupport issue happening Mac 1114 Safari reading email today text message Please fix                                                                                                                                    |negative |
# |AppleSupport   |341892 assist One option free storage space space available httpstco7vNd2QAL5s also purchase iCloud storage                                                                                                                 |positive |
# |AppleSupport   |725629 Wed happy take look happened Dock iPad still happening restart iPad fix                                                                                                                                              |positive |
# |725629         |thisssss 115858 AppleSupport  Worst update ever httpstcoQt2KWH5IEC                                                                                                                                                          |neutral  |
# |AppleSupport   |725630 want help Open Clock app go Alarm tap Edit see Snooze option alarm                                                                                                                                                   |negative |
# |725630         |AppleSupport Yes turned always turn Unless green means                                                                                                                                                                      |neutral  |
# |AppleSupport   |725630 Thanks confirming Weve got DM well continue working                                                                                                                                                                  |positive |
# |725630         |Another day Another morning without snooze button 1000 iPhone snooze button 115858 amp AppleSupport snooze button app Obvs want fancy things                                                                                |positive |
# |AppleSupport   |384773 love hearing feedback suggestions httpstcoeTPVYVFyd8                                                                                                                                                                 |positive |
# |384773         |AppleSupport Done                                                                                                                                                                                                           |neutral  |
# |384773         |AppleSupport Apple add feature face id required go nonsmiling smiling order unlock phone                                                                                                                                    |positive |
# |AppleSupport   |725632 Lets take look together already updated iPhone iOS 1111  apps crashing hot using charging Let us know DM well get started httpstcoGDrqU22YpT                                                                         |positive |
# |AppleSupport   |193026 Youve come right place help Whats going iPhone X                                                                                                                                                                     |positive |
# |193026         |AppleSupport Static noise listening music one Assistive touch button going random part screen time move back eventually goes back spot                                                                                      |negative |
# |AppleSupport   |193026 want help tell us iOS version Settings gt General gt tell                                                                                                                                                            |neutral  |
# |193026         |AppleSupport 1111                                                                                                                                                                                                           |neutral  |
# |AppleSupport   |193026 Thank DM us well continue steps httpstcoGDrqU22YpT                                                                                                                                                                   |positive |
# |AppleSupport   |725633 want enjoy iPhone new feature offered update Please tell us specific issues youre experiencing well happy look                                                                                                       |positive |
# |725633         |115858 iOS 11 ruined iPhone experience guys need fix ASAP Way many bugs glitches                                                                                                                                            |negative |
# |AppleSupport   |725634 know depend iPhone work properly wed like look issues iOS version installed Youll find Settings gt General gt                                                                                                        |positive |
# |AppleSupport   |725635 Lets make sure getting battery Let us know helps httpstcobivpdfBNJ6                                                                                                                                                  |neutral  |
# |AppleSupport   |630997 Wed like help figure whats going screenshots device happening see screenshot Photos app                                                                                                                              |positive |
# |630997         |AppleSupport iPhone X yes appear photos                                                                                                                                                                                     |neutral  |
# |AppleSupport   |630997 OK iOS running currently go Settings gt General gt locate version \nHas ever worked youd expect \nHave restarted iPhone since noticed behavior                                                                       |positive |
# |AppleSupport   |381848 Great question go Settings gt Camera gt Preserve Settings turn Live Photos go Camera app turn Live Photos option                                                                                                     |neutral  |
# |381848         |AppleSupport keep Live Photo turned permanently                                                                                                                                                                             |neutral  |
# |AppleSupport   |248333 Since Twitter support available English get help httpstcoIBIY3vMgPj join httpstcopvaOFfPbjt                                                                                                                          |positive |
# |AppleSupport   |725636 want help Tell us bit happening start getting everything fixed                                                                                                                                                       |neutral  |
# |725636         |AppleSupport phone running perfect iOS 11                                                                                                                                                                                   |positive |
# |AppleSupport   |725636 Thanks details update right iOS 10 iOS 1111 notice slowness earlier versions iOS 11 \n\nAdditionally country located Let us know DM httpstcoGDrqU22YpT                                                               |positive |
# |AppleSupport   |725637 behavior wed want phone Click join us DM let us know iPhone software version youre using httpstcoGDrqU22YpT                                                                                                          |neutral  |
# |725637         |115858 fix shit phone crash every fucking day httpstco9VOVXhDMxN                                                                                                                                                            |negative |
# |AppleSupport   |638684 Wed like look Click join us DM Well assist httpstcoGDrqU22YpT                                                                                                                                                        |positive |
# |AppleSupport   |725638 Wed happy help join us DM tell us whats happening iPhone httpstcoGDrqU22YpT                                                                                                                                          |positive |
# |AppleSupport   |725640 Lets meet DM httpstcoGDrqU22YpT                                                                                                                                                                                      |neutral  |
# |725640         |AppleSupport Case 100349925315 headphone working service center resolving case                                                                                                                                              |neutral  |
# |AppleSupport   |665962 never want hear Reach us DM well help httpstcoGDrqU22YpT                                                                                                                                                             |positive |
# |665962         |AppleSupport upset Sunday wanted man fired spot                                                                                                                                                                             |negative |
# |AppleSupport   |725641 help Lets take look exact iOS version apps updates App Store                                                                                                                                                         |neutral  |
# |725641         |AppleSupport Im worried frequency phone crashes Ive sometimes even apps open                                                                                                                                                |negative |
# |725641         |AppleSupport current iOS version 1111\nI enabled auto  updates apps                                                                                                                                                         |neutral  |
# |AppleSupport   |725641 OK thank noticed happens youre using particular apps anything particular  iPhone restarted since noticed issue                                                                                                       |positive |
# |725641         |AppleSupport Normally afternoon close running apps return home screen morning phone froze skipping songs iPhone music player perform force restart                                                                          |negative |
# |AppleSupport   |725641 OK thank issues prior updating Whcih version software installed first noticed Let us know DM well go httpstcoGDrqU22YpT                                                                                              |positive |
# |725641         |AppleSupport installing iOS 11 iPhone 6 lot apps crashing sometimes freezes entire phone force restart everytime happens Furthermore apps seem lag whilst launching eg Youtube new update coming 12                         |negative |
# |AppleSupport   |725642 Thanks reaching us know important device functioning way youd like Well help best Lets meet DM work together httpstcoGDrqU22YpT                                                                                      |positive |
# |725642         |applesupport updated version 1111 6 Still immediately plagued delayed app responses iOS app crashes                                                                                                                         |negative |
# |AppleSupport   |725643 Wed happy help Send us DM details httpstcoGDrqU22YpT                                                                                                                                                                 |positive |
# |725643         |Okay 115858 updated phone still seeing glitch Thoughts straw breaks camel switch galaxy                                                                                                                                     |negative |
# |AppleSupport   |655192 want everything work properly iPhone want make sure understand exactly whats going sounds like youre unable turn Airplane mode device correct get error messages try disable                                         |positive |
# |655192         |AppleSupport error messages anything                                                                                                                                                                                        |negative |
# |AppleSupport   |655192 Great details Thanks sending iOS version installed iPhone find Settings gt General gt Please DM us httpstcoGDrqU22YpT                                                                                                |neutral  |
# |655192         |AppleSupport sometimes works goes back normal sometimes like morning wont turn hit button lot                                                                                                                               |positive |
# |655192         |AppleSupport happens try turning Ill hit button airplane symbol wont go away  httpstco7XgGpu5Mdm                                                                                                                            |neutral  |
# |655192         |AppleSupport want tell phone put airplane mode turned symbol wont go away turn                                                                                                                                              |neutral  |
# |comcastcares   |725644 Hello happy assist line concerns please DM name address phone number account MLR                                                                                                                                     |positive |
# |725644         |comcastcares mind tech today cutting ground cable bury since March httpstcoi6p6fyPFmN                                                                                                                                       |neutral  |
# |AppleSupport   |409630 Wed happy look Please DM us bit whats going well continue httpstcoGDrqU22YpT                                                                                                                                         |positive |
# |409630         |AppleSupport need arrange three separate repairs  One left AirPod one right AirPod one case                                                                                                                                 |positive |
# |409630         |Excellent job AppleSupport  charge 207 159 set AirPods failed warranty Ive cut twice go investigate stupid httpstcoXZhbh8n8V7                                                                                               |negative |
# |AppleSupport   |725645 safety number one concern Please send us DM including country youre located httpstcoGDrqU22YpT                                                                                                                       |negative |
# |AppleSupport   |725646 exactly seeing happen Well happy assist best                                                                                                                                                                         |positive |
# |725646         |updated shit last week still fucking 115858                                                                                                                                                                                 |negative |
# |AppleSupport   |725647 Hello thanks reaching Lets see whats going Apple Music thing happen WiFi                                                                                                                                             |neutral  |
# |725647         |AppleSupport works fine                                                                                                                                                                                                     |positive |
# |AppleSupport   |725647 ever able play videos Apple Music using cellular iPhone yes anything different working upgrade iOS new app                                                                                                           |neutral  |
# |AppleSupport   |725647 able stream videos sources Apple Music cellular                                                                                                                                                                      |neutral  |
# |725647         |AppleSupport Yes works Safari checked also checked another friend Apple Music subscription iPhone 7 Plus iOS 1111 play videos cellular data Apple Music Wifi works                                                          |positive |
# |AppleSupport   |725647 Lets check couple settings Please go Settings gt Cellular Music enabled Settings gt Music want make sure Cellular Data also Please DM us results httpstcoGDrqU22YpT                                                  |neutral  |
# |725647         |AppleSupport encounter error trying play videos 115948 iPhone 7 iOS 1111 Mobile data streaming playing music works wo problems httpstcoTPJJ4K4j98                                                                           |positive |
# |AppleSupport   |450493 Wed glad help Send us DM go httpstcoGDrqU22YpT                                                                                                                                                                       |positive |
# |AppleSupport   |725648 Wed like help using TV app content showing downloaded device viewing offline Also whats current version iOS Settings gt General gt                                                                                   |positive |
# |AppleSupport   |725649 Wed like help Let us know device youre using system version installed via DM Well go httpstcoGDrqU22YpT                                                                                                              |positive |
# |AppleSupport   |725650 Wed like see assist start happening confirm fully uptodate running iOS 1111                                                                                                                                          |positive |
# |AppleSupport   |725651 Wed like help Heres information making changes Apple ID httpstcoxuZEqdPMFW                                                                                                                                           |positive |
# |725651         |AppleSupport tried says iCloud email address invalid even though correct ideas                                                                                                                                              |positive |
# |AppleSupport   |725651 trying change Apple ID sign every Apple service device httpstcoEM9FLitibK                                                                                                                                            |neutral  |
# |725651         |AppleSupport iPhone devices sign using phones settings app described link sent                                                                                                                                              |neutral  |
# |AppleSupport   |725651 Lets make sure youre signed Apple ID iPhone computer go httpstcoGCy9eQm7Th  sign current Apple ID edit email address doesnt work let us know via DM httpstcoGDrqU22YpT                                               |positive |
# |725651         |AppleSupport want change AppleID 133941 address iCloud email account Ive created  please Thanks advance                                                                                                                     |neutral  |
# |AppleSupport   |725652 understand concerns chance look information maximizing battery life iPhone link review httpstcobivpdfBNJ6\n\nIf youre still issues send us DM wed happy help httpstcoGDrqU22YpT                                      |positive |
# |AppleSupport   |725652 Perfect thanks looking steps want see theres anything else done assist battery life device Please meet us DM gather information better assist httpstcoGDrqU22YpT                                                     |positive |
# |AppleSupport   |160220 Hi happy get pointed right direction purchase screen protector Apple Store Let us know DM httpstcoGDrqU22YpT                                                                                                         |positive |
# |160220         |AppleSupport Yes purchased put store special machine                                                                                                                                                                        |neutral  |
# |AppleSupport   |160220 OK suggest contacting Apple Store purchased Find information httpstcom3VXPZgbmD                                                                                                                                      |neutral  |
# |160220         |AppleSupport screen protector already coming Seriously never many problems iphone iphone8plus protector put 115858 3 weeks old today                                                                                        |negative |
# |AppleSupport   |725653 happy hear situation options available Find iPhone service Lost Mode tips Learn httpstcofUoKdx4Yut                                                                                                                   |positive |
# |725653         |hey AppleSupport  115858 love find Iphone feature doesnt really help someone steals phone Netherlands ships  Romania                                                                                                        |positive |
# |AppleSupport   |725654 Wed like look whats causing lagging restarting youre seeing start tell us bit youre seeing lagging restarts happen also tell us iPhone iOS version youre using                                                       |positive |
# |AppleSupport   |332464 glad hear Photos returned Let us know need help anything future httpstcoGDrqU22YpT                                                                                                                                   |positive |
# |AppleSupport   |725655 happy look clarify seeing occur messages youre sending messages received contacts                                                                                                                                    |positive |
# |AppleSupport   |266998 Wed like look issues Let us know model iPhone youre using DM Well go httpstcoGDrqU22YpT                                                                                                                              |positive |
# |266998         |Terrible battery life iPhone overheating IOS1111 expensive phone retailer world Sort AppleSupport                                                                                                                           |negative |
# |AppleSupport   |597465 want help Send us DM well look httpstcoGDrqU22YpT                                                                                                                                                                    |positive |
# |146595         |597465 115858 O2 Hi David dont investigate complaints Apple products theres lot advice online maximising battery lifespan eg httpstcojRr38TGA8q                                                                             |negative |
# |AppleSupport   |159626 want Siri working well help get started type iPhone using iOS version currently installed find iOS going Settings gt General gt                                                                                      |positive |
# |AppleSupport   |725658 appreciate taking time get contact us today happy look Please send us DM httpstcoGDrqU22YpT                                                                                                                          |positive |
# |725658         |AppleSupport 115858  10 Months old iphone 6s touch id working night mare Service center guys need 10 days 4 service night mare 2 appreciated \n\nPlz contact 7356202500 httpstcoQJS62dZgah                                  |positive |
# |AppleSupport   |725659 Follow us DM Tell us reason call support Well see help httpstcoGDrqU22YpT                                                                                                                                            |positive |
# |725659         |AppleSupport call always drop minutes put hold hear beep beep beep beep every seconds couple minutes call drops                                                                                                             |neutral  |
# |Uber_Support   |725660 help sent DM                                                                                                                                                                                                         |neutral  |
# |725660         |Uber_Support                                                                                                                                                                                                                |neutral  |
# |Uber_Support   |725660 Sorry trouble Please send us DM email address phone number connect                                                                                                                                                   |negative |
# |Uber_Support   |725661 help Simply contact us via httpstcozJ6aIZinzb team assist                                                                                                                                                            |neutral  |
# |725661         |Uber_Support Cool thanks                                                                                                                                                                                                    |neutral  |
# |725661         |Hi 115873 guys billed twice trip yesterday wondering long gets corrected                                                                                                                                                    |neutral  |
# |Uber_Support   |725662 help Send us note httpstcooEOANqFpjc team connect                                                                                                                                                                    |neutral  |
# |725662         |Uber_Support 2 KM distance Uber charge 9182 Rs please help resolved Distance travell 2 KM receipt showing distance 18 km                                                                                                    |neutral  |
# |Uber_Support   |725663 Hi Vikram Weve located support inquiry member team following momentarily appreciate patience understanding thus far                                                                                                  |positive |
# |725663         |Dear 116276 must consider changing 116288 11590 headteam working ethos 115873  Badly managed services mishandled complaints sure working uber rivals                                                                        |negative |
# |Uber_Support   |656005 team following appreciate patience                                                                                                                                                                                   |positive |
# |656005         |Uber_Support hope oneoff experience hasnt changed perception Uber great day ahead  Oneoff experience didnt change perception inadequate response                                                                            |positive |
# |656005         |Uber_Support course  result ran foot Woops sorry heres refund fucking cut FOH Uber                                                                                                                                          |positive |
# |Uber_Support   |656005 Happy help appears member team followed inapp support inquiry Please check messages Help section app assistance                                                                                                      |positive |
# |656005         |115873s driver ran foot refund trip Thanks 115873 \n\nIn news 115879  WYD                                                                                                                                                   |positive |
# |Uber_Support   |260235 help Send us note httpstcouRjsQ64qLY team touch                                                                                                                                                                      |neutral  |
# |260235         |Uber_Support updated insurance couple weeks ago got text asking insurance placed hold Trying find contact luck                                                                                                              |positive |
# |Uber_Support   |725664 take seriously Please send us DM email address connect ASAP                                                                                                                                                          |neutral  |
# |725664         |Uber_Support Driver Rana Pratap car UP14FT5662 abusive threatening family Delhi airport Terminal 1 arrival Please take control situation ASAP httpstcoemVK0sAEMK                                                            |negative |
# |Uber_Support   |725665 Hi help Send us note httpstcoZFaWy0Lkdu team assist                                                                                                                                                                  |neutral  |
# |725665         |Uber_Support Cool thanks                                                                                                                                                                                                    |neutral  |
# |Uber_Support   |725666 help Send us note via httpstcoe8HVorX5rh team connect                                                                                                                                                                |neutral  |
# |Uber_Support   |264357 Hi help Send us note httpstcoEGiaYE5JMU team assist                                                                                                                                                                  |neutral  |
# |264357         |Uber_Support  disappointed UberEATS City Ghent Belgium 1 hour late order incomplete yet billed full                                                                                                                         |negative |
# |Uber_Support   |725667 Hi Please reach httpstcozUe0dj6yoX fill 4 boxes bottom get touch                                                                                                                                                     |neutral  |
# |725667         |Dear 115873  advertisement makes app worthless us using large fonts msg dismissed httpstcopHMemX6R7h                                                                                                                        |negative |
# |Uber_Support   |725668 help Send us note via httpstcoWJq5jsdLlf team connect                                                                                                                                                                |neutral  |
# |725668         |Uber_Support charged waiting fee ride last night waited 20 minutes picked driver wait                                                                                                                                       |neutral  |
# |Uber_Support   |238901 help Send us DM email address assist                                                                                                                                                                                 |neutral  |
# |Uber_Support   |725669 Happy assist please send us DM email address additional details                                                                                                                                                      |neutral  |
# |SpotifyCares   |725670 Hi get lyrics annotations tracks via partnership Genius info httpstcomvyCo4ndOe Give us shout need anything else DN                                                                                                  |neutral  |
# |725670         |SpotifyCares Hmm                                                                                                                                                                                                            |neutral  |
# |725671         |SpotifyCares Thanks babe                                                                                                                                                                                                    |neutral  |
# |725671         |SpotifyCares yo saved albumssongs every awhile like undownload Super annoying                                                                                                                                               |positive |
# |SpotifyCares   |725672 Hey Gavin sometimes content gets temporarily removed licensing changes Hopefully well available soon BX                                                                                                              |positive |
# |SpotifyCares   |725673 Hey Andrew Sometimes content temporarily removed licensing changes Hopefully well available soon Theres info httpstcoVE7KvznUs9 JI                                                                                   |positive |
# |725673         |115888 ummm Take Care suddenly non existent httpstcoWK1ubV01Dw                                                                                                                                                              |neutral  |
# |SpotifyCares   |400838 Hey Mathieu helps country Spotify account set Well take look backstage TB                                                                                                                                            |neutral  |
# |400838         |SpotifyCares France usual never change                                                                                                                                                                                      |neutral  |
# |400838         |SpotifyCares  hope                                                                                                                                                                                                          |neutral  |
# |400838         |SpotifyCares Hi really drop Archive  Lights album platform                                                                                                                                                                  |neutral  |
# |SpotifyCares   |725674 Hi Bradley cavalrys DM us accounts email address Well take look backstage AU httpstcoldFdZRiNAt                                                                                                                      |neutral  |
# |725674         |115888 rest Take Care 6 songs httpstcolxTWBtF18I                                                                                                                                                                            |neutral  |
# |725675         |SpotifyCares  issues logging                                                                                                                                                                                                |negative |
# |SpotifyCares   |725676 Hey Armando Sometimes content gets temporarily removed licensing changes Hopefully well available soon KL                                                                                                            |positive |
# ...
# |SouthwestAir   |725920 Oh apologies Konner Feel free reach Flight Attendant still havent received drink SF                                                                                                                                  |positive |
# |SouthwestAir   |265183 hopeful youll get fly one soon Richard VM                                                                                                                                                                            |positive |
# |265183         |737800 scimitar winglet SouthwestAir  Still havent seen elusive Max natural habitat even really exist httpstcoksygGh7YVS                                                                                                    |neutral  |
# |SouthwestAir   |725921 Truly sorry frustration WiFi onboard Ryan Feel free DM flight confirmation number assistance NG httpstcomQmfkXW4oV                                                                                                   |positive |
# |725921         |wasting time trying get Kennedys  SouthwestAir wifi 60588                                                                                                                                                                   |negative |
# |SouthwestAir   |725922 needs manually added reservation booking process arent logged time booking DM KTN confirmation number late add NA                                                                                                    |neutral  |
# |725922         |SouthwestAir Thanks quick response DMing shortly                                                                                                                                                                            |neutral  |
# |725923         |British_Airways Hi BA Team travelling Cuba via Madrid Iberia months offer Cuban travel card Thank                                                                                                                           |neutral  |
# |British_Airways|725924 Hi Manish sorry hear recent experience DM us full name booking reference email address home address look Cody                                                                                                        |negative |
# |725924         |British_Airways paid seat even charging seat changed flight BA793                                                                                                                                                           |neutral  |
# |British_Airways|523060 Hi Im sorry hear cancellation  managed rebooked  Tom                                                                                                                                                                 |negative |
# |British_Airways|523060 Hi sorry  look see alternatives  spoken anyone change  please DM us booking reference telephone number email postal addresses  Jm                                                                                    |negative |
# |523060         |British_Airways Yeah spoken someone well sister travel agent TUI DM Thank                                                                                                                                                   |positive |
# |British_Airways|470635 tried different browser Suresh seems website working fine Explorer Apologies inconvenience caused Monica                                                                                                             |positive |
# |470635         |British_Airways tried across IE Firefox Safari Chrome issue occurs try get Executive Club page across browsers                                                                                                              |negative |
# |470635         |British_Airways website seems nonfunctional httpstcopzOhYgyqgb                                                                                                                                                              |neutral  |
# |British_Airways|725926 Hi Ross  Im sorry hear however dont process name changes ticket explains terms conditions ticket Tom                                                                                                                 |negative |
# |British_Airways|725926 Hi Ross Conditions Carriage advise regulations long theres availability make new booking travel brother Helen                                                                                                        |neutral  |
# |725926         |British_Airways Yes loose 850 wrong immoral                                                                                                                                                                                 |negative |
# |British_Airways|725926 sorry feel way Ross Well certainly feed back comments Charlotte                                                                                                                                                      |negative |
# |725926         |British_Airways cant change name ticket Well loose money flight fill someone else make trip much better                                                                                                                     |positive |
# |British_Airways|725927 Hi Andy Im sorry hear problems online team aware issue working hard try get fixed mean time anything particular help  Tom                                                                                            |negative |
# |725927         |British_Airways Hi  update page still seems Many thanks                                                                                                                                                                     |neutral  |
# |British_Airways|725927 Hi Andy Well check Exactly page trying access error displayed Natalie                                                                                                                                                |negative |
# |725927         |British_Airways Hi  aware issues Executive Club moment Getting error  tried multiple browsers Many thanks Andy httpstco6SWoY25GoN                                                                                           |negative |
# |British_Airways|725928 Hi Marc Im sorry hear problems online aware issue team working hard get fixed mean time anything help  Tom                                                                                                           |negative |
# |725928         |British_Airways Thanks Tom cleared history etc edge internet browser began working Something obviously stored ticket purchased think Thanks lot                                                                             |positive |
# |British_Airways|725928 Hi Marc Im glad managed work anything need assistance please dont hesitate get contact Tom                                                                                                                           |positive |
# |725928         |British_Airways thanks Tom                                                                                                                                                                                                  |neutral  |
# |725928         |British_Airways problems site Made 2 bookings today amp browsers arent working Reference S000678328  IP 901520212\nI first used chrome book first flight browser stopped working httpstco5hMUxR7Fbu used edge stopped       |negative |
# |British_Airways|725929 Hi Rowan reported team meantime anything assist   Tom                                                                                                                                                                |neutral  |
# |725929         |British_Airways Need provide apis check insite still maybe need get new people                                                                                                                                              |neutral  |
# |725929         |British_Airways website seems gone                                                                                                                                                                                          |neutral  |
# |GloCare        |725930 117627 Good evening inform management revert Thank AP                                                                                                                                                                |negative |
# |725930         |GloCare 117627 immediate solution matter                                                                                                                                                                                    |neutral  |
# |GloCare        |725930 117627 Kindly send 4G 400 know phone compatibleET                                                                                                                                                                    |neutral  |
# |725930         |GloCare 117627 got response                                                                                                                                                                                                 |neutral  |
# |GloCare        |725930 117627 Kindly note device band 28for 4G compatible CA                                                                                                                                                                |positive |
# |725930         |GloCare 117627 hope phones without band 28 get 4G anytime soon                                                                                                                                                              |neutral  |
# |GloCare        |725930 117627 Hello information moment Thank DA                                                                                                                                                                             |neutral  |
# |725930         |GloCare 117627 possible hope 4G compatibility Infinix devices time soon                                                                                                                                                     |neutral  |
# |GloCare        |725931 117627 Okay AP                                                                                                                                                                                                       |neutral  |
# |725931         |Dear Glo 117627 GloCare got complaints lodge Pls follow dm Thanks                                                                                                                                                           |negative |
# |GloCare        |445606 Sincere apologies kindly provide number device type exact location landmark error message signal see alternate number AP                                                                                             |positive |
# |445606         |GloCare cnt access d internet nd network                                                                                                                                                                                    |neutral  |
# |GloCare        |445606 Sincere apologies kindly provide number device type exact location landmark error message signal see alternate number AP                                                                                             |positive |
# |445606         |GloCare cnt browse d internet                                                                                                                                                                                               |neutral  |
# |GloCare        |150672 5566 122461 725932 apologize May know exact issue AP                                                                                                                                                                 |negative |
# |150672         |GloCare 5566 122461 725932 sad                                                                                                                                                                                              |negative |
# |150672         |GloCare 5566 122461 725932 98408 worry nd sad way nd manners Nigeria telecommunication industry run countryi registered gloline08152080886 fg deals MTN give beneficiaries devices sad MTN treat cubeMTNline first          |negative |
# |150672         |GloCare 5566 122461 725932 MTNline MTN center sent pickup sms NPOWER Samsung devices nd gloline find difficulteven friends Oyo state didnt receive MTN center later gave httpstcoJiCceh6hfD want line first others bad      |negative |
# |150672         |GloCare 5566 122461 725932 regretted registerd NPOWER gloline08152080886 friends using MTNline seen Samsung pickup sms today Even friends Oyo re using gloline didnt receive sms went Samsung                               |negative |
# |GloCare        |725933 Evening kindly provide number quick check AP                                                                                                                                                                         |positive |
# |725933         |GloCare 08058328896                                                                                                                                                                                                         |neutral  |
# |725933         |GloCare still waiting fa                                                                                                                                                                                                    |neutral  |
# |GloCare        |725933 kindly provide number quick checkEE                                                                                                                                                                                  |positive |
# |725933         |GloCare Number 08058328896 kindly unsubscribe tips tunes services thereby stop deducting airtime also want know d tariff plan im presently bonus data yet airtime deducted whenever connect internet                        |positive |
# |GloCare        |725933 Good morning negative deduction observed line However text STOP 2442 deactivate unsolicited services Jumbo sim package Calls Main ac38ksec Calls Bonus ac 80ks strictly Glo glo SMS N4                               |negative |
# |725933         |GloCare Thanks airtime deducted internet connectivity                                                                                                                                                                       |neutral  |
# |GloCare        |725933 welcome APN presently PAYUpay use means charged either credit bonus presently browsing form bonus account airtime GA                                                                                                 |positive |
# |725933         |GloCare Kindly help change APN                                                                                                                                                                                              |neutral  |
# |GloCare        |725933 Please go device settings click APNtype gloflatscroll username type flatclick password type flat save exit                                                                                                           |neutral  |
# |725933         |GloCare bonus data APN set flat airtime still deducted Need Solution                                                                                                                                                        |positive |
# +---------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# only showing top 1000 rows

# %% [markdown]
# ### Save to Data Warehouse

# %% [markdown]
# Create database

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS db_tgp2")
# Out:
# DataFrame[]

# %% [markdown]
# Schema-on-Write

# %%
spark.sql("USE db_tgp2")
spark.sql("CREATE TABLE IF NOT EXISTS customer_tweets (id BIGINT GENERATED ALWAYS AS IDENTITY, author_id STRING, inbound STRING, created_at STRING, text STRING, text_clean STRING, response_tweet_id STRING, in_response_to_tweet_id STRING, sentiment STRING) USING hive")
# Out:
# DataFrame[]

# %% [markdown]
# Write dataframe to Hive Table

# %%
df_twcs_clean.write.mode("overwrite").format("hive").saveAsTable("db_tgp2.customer_tweets")

# %% [markdown]
# Test inserted data

# %%
df = spark.sql("SELECT * FROM customer_tweets LIMIT 1000")
df.show()
# Out:
# +--------------------+--------+------------+-------+--------------------+--------------------+--------------------+-----------------------+--------------------+--------------------+---------+
# |     timestamp_kafka|tweet_id|   author_id|inbound|          created_at|                text|   response_tweet_id|in_response_to_tweet_id|          text_clean|              tokens|sentiment|
# +--------------------+--------+------------+-------+--------------------+--------------------+--------------------+-----------------------+--------------------+--------------------+---------+
# |2025-06-26 15:54:...| 2555292|AppleSupport|  false|Thu Nov 16 16:05:...|@246955 Thanks fo...|             2555293|                2555294|246955 Thanks con...|[Thanks, contacti...| positive|
# |2025-06-26 15:54:...| 2555293|      246955|   true|Thu Nov 16 19:28:...|@AppleSupport Yes...|             2555295|                2555292|AppleSupport Yes ...|[AppleSupport, Ye...|  neutral|
# |2025-06-26 15:54:...| 2555295|AppleSupport|  false|Thu Nov 16 20:46:...|@246955 Let's kee...|                    |                2555293|246955 Lets keep ...|[Lets, keep, eye,...| positive|
# |2025-06-26 15:54:...| 2555296|AppleSupport|  false|Thu Nov 16 16:05:...|@725612 We'd be h...|                    |                2555297|725612 Wed happy ...|[Wed, happy, assi...| positive|
# |2025-06-26 15:54:...| 2555297|      725612|   true|Thu Nov 16 13:37:...|@AppleSupport hi....|             2555296|                       |AppleSupport hi m...|[AppleSupport, hi...| positive|
# |2025-06-26 15:54:...| 2555299|      725613|   true|Thu Nov 16 13:48:...|@115858 #ios11.1....|             2555298|                       |115858 ios1111Bug...|[ios1111Bug, kill...| negative|
# |2025-06-26 15:54:...| 2555300|AppleSupport|  false|Thu Nov 16 16:04:...|@725614 Let's tak...|                    |                2555301|725614 Lets take ...|[Lets, take, look...| positive|
# |2025-06-26 15:54:...| 2555301|      725614|   true|Thu Nov 16 14:01:...|@AppleSupport whe...|             2555300|                       |AppleSupport real...|[AppleSupport, re...| negative|
# |2025-06-26 15:54:...| 2555302|AppleSupport|  false|Thu Nov 16 16:03:...|@725615 That cert...|                    |                2555303|725615 certainly ...|[certainly, isnt,...| positive|
# |2025-06-26 15:54:...| 2555304|AppleSupport|  false|Thu Nov 16 16:03:...|@725616 Thanks fo...|                    |                2555305|725616 Thanks con...|[Thanks, contacti...| positive|
# |2025-06-26 15:54:...| 2555305|      725616|   true|Thu Nov 16 13:44:...|@AppleSupport My ...|             2555304|                       |AppleSupport iPho...|[AppleSupport, iP...| negative|
# |2025-06-26 15:54:...| 2555307|      725617|   true|Thu Nov 16 13:33:...|Hi @AppleSupport ...|2555308,2555309,2...|                       |Hi AppleSupport w...|[Hi, AppleSupport...|  neutral|
# |2025-06-26 15:54:...| 2555311|AppleSupport|  false|Thu Nov 16 16:02:...|@725618 We'll do ...|                    |                2555312|725618 Well much ...|[Well, much, help...|  neutral|
# |2025-06-26 15:54:...| 2555313|AppleSupport|  false|Thu Nov 16 16:02:...|@725619 Let's joi...|             2555314|                2555315|725619 Lets join ...|[Lets, join, toge...| negative|
# |2025-06-26 15:54:...| 2555314|      725619|   true|Thu Nov 16 16:34:...|@AppleSupport Yes...|             2555316|                2555313|AppleSupport Yes ...|[AppleSupport, Ye...| positive|
# |2025-06-26 15:54:...| 2555316|AppleSupport|  false|Thu Nov 16 17:42:...|@725619 Thanks fo...|                    |                2555314|725619 Thanks inf...|[Thanks, informat...| positive|
# |2025-06-26 15:54:...| 2555315|      725619|   true|Thu Nov 16 12:59:...|The iOS update ha...|             2555313|                       |iOS update render...|[iOS, update, ren...| negative|
# |2025-06-26 15:54:...| 2555320|AppleSupport|  false|Thu Nov 16 17:02:...|@725620 Thanks fo...|                    |                2555318|725620 Thanks cla...|[Thanks, clarifyi...|  neutral|
# |2025-06-26 15:54:...| 2555319|      725620|   true|Thu Nov 16 13:47:...|WHY DO I STILL SE...|             2555317|                       |STILL SEE BOXES U...|[STILL, SEE, BOXE...|  neutral|
# |2025-06-26 15:54:...| 2555321|AppleSupport|  false|Thu Nov 16 16:02:...|@725621 We can he...|             2555322|                2555323|725621 help devic...|[help, device, us...|  neutral|
# +--------------------+--------+------------+-------+--------------------+--------------------+--------------------+-----------------------+--------------------+--------------------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Save cleaned data to Data Lake

# %%
df_twcs_clean.write.mode("overwrite").format("parquet").save("hdfs://localhost:9000/hdfs_twcs_clean")

# %%
df2 = spark.read.parquet("hdfs://localhost:9000/hdfs_twcs_clean")
df2.show(10, truncate=False)
# Out:
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |timestamp_kafka        |tweet_id|author_id   |inbound|created_at                    |text                                                                                                                                                                                                                                                               |response_tweet_id|in_response_to_tweet_id|text_clean                                                                                                                                                                      |tokens                                                                                                                                                                                     |sentiment|
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |2025-06-26 15:54:19.72 |2555292 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@246955 Thanks for contacting us. We can understand how important it is to have your alarms working properly. Are you able to re-add the alarm without issue?                                                                                                      |2555293          |2555294                |246955 Thanks contacting us understand important alarms working properly able readd alarm without issue                                                                         |[Thanks, contacting, us, understand, important, alarms, working, properly, able, readd, alarm, without, issue]                                                                             |positive |
# |2025-06-26 15:54:19.72 |2555293 |246955      |true   |Thu Nov 16 19:28:52 +0000 2017|@AppleSupport Yes I added it back                                                                                                                                                                                                                                  |2555295          |2555292                |AppleSupport Yes added back                                                                                                                                                     |[AppleSupport, Yes, added, back]                                                                                                                                                           |neutral  |
# |2025-06-26 15:54:19.72 |2555295 |AppleSupport|false  |Thu Nov 16 20:46:00 +0000 2017|@246955 Let's keep an eye on it and see if the issue comes back. If it does, let us know. Also, if you haven't already done so, we'd recommend making sure the iOS is updated. Please be sure to back up prior to updating: https://t.co/80YRnjVguS                |                 |2555293                |246955 Lets keep eye see issue comes back let us know Also havent already done wed recommend making sure iOS updated Please sure back prior updating httpstco80YRnjVguS         |[Lets, keep, eye, see, issue, comes, back, let, us, know, Also, havent, already, done, wed, recommend, making, sure, iOS, updated, Please, sure, back, prior, updating, httpstco80YRnjVguS]|positive |
# |2025-06-26 15:54:19.72 |2555296 |AppleSupport|false  |Thu Nov 16 16:05:35 +0000 2017|@725612 We'd be happy to assist with your music today. Send us a DM to get started. https://t.co/GDrqU22YpT                                                                                                                                                        |                 |2555297                |725612 Wed happy assist music today Send us DM get started httpstcoGDrqU22YpT                                                                                                   |[Wed, happy, assist, music, today, Send, us, DM, get, started, httpstcoGDrqU22YpT]                                                                                                         |positive |
# |2025-06-26 15:54:19.721|2555297 |725612      |true   |Thu Nov 16 13:37:56 +0000 2017|@AppleSupport hi. Why is my music coming up like this. I've downloaded it already https://t.co/brZgMhddnt                                                                                                                                                          |2555296          |                       |AppleSupport hi music coming like Ive downloaded already httpstcobrZgMhddnt                                                                                                     |[AppleSupport, hi, music, coming, like, Ive, downloaded, already, httpstcobrZgMhddnt]                                                                                                      |positive |
# |2025-06-26 15:54:19.721|2555299 |725613      |true   |Thu Nov 16 13:48:01 +0000 2017|@115858 #ios11.1.1Bug is killing all the #iPhoneSE versions. After the update, iphones which were normally working were started being frozen and stuck with  an #appleLogo on a black screen and started the restart game. Apple a fix please. @99089 @99088 Still?|2555298          |                       |115858 ios1111Bug killing iPhoneSE versions update iphones normally working started frozen stuck  appleLogo black screen started restart game Apple fix please 99089 99088 Still|[ios1111Bug, killing, iPhoneSE, versions, update, iphones, normally, working, started, frozen, stuck, , appleLogo, black, screen, started, restart, game, Apple, fix, please, Still]       |negative |
# |2025-06-26 15:54:19.721|2555300 |AppleSupport|false  |Thu Nov 16 16:04:03 +0000 2017|@725614 Let's take a look at this together. When you restore, are you using iTunes or are you erasing your iPhone from the Settings? Let us know in DM and we'll team up to get this resolved. https://t.co/GDrqU22YpT                                             |                 |2555301                |725614 Lets take look together restore using iTunes erasing iPhone Settings Let us know DM well team get resolved httpstcoGDrqU22YpT                                            |[Lets, take, look, together, restore, using, iTunes, erasing, iPhone, Settings, Let, us, know, DM, well, team, get, resolved, httpstcoGDrqU22YpT]                                          |positive |
# |2025-06-26 15:54:19.721|2555301 |725614      |true   |Thu Nov 16 14:01:05 +0000 2017|@AppleSupport when will you realize your stupid update problem that makes me restore my iPhone daily?                                                                                                                                                              |2555300          |                       |AppleSupport realize stupid update problem makes restore iPhone daily                                                                                                           |[AppleSupport, realize, stupid, update, problem, makes, restore, iPhone, daily]                                                                                                            |negative |
# |2025-06-26 15:54:19.721|2555302 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725615 That certainly isn't expected and we would love to help take a look at this. Go ahead and reach out to us in DM and tell us more about what's going on. We will definitely help get on a path to getting this resolved. https://t.co/GDrqU22YpT            |                 |2555303                |725615 certainly isnt expected love help take look Go ahead reach us DM tell us whats going definitely help get path getting resolved httpstcoGDrqU22YpT                        |[certainly, isnt, expected, love, help, take, look, Go, ahead, reach, us, DM, tell, us, whats, going, definitely, help, get, path, getting, resolved, httpstcoGDrqU22YpT]                  |positive |
# |2025-06-26 15:54:19.721|2555304 |AppleSupport|false  |Thu Nov 16 16:03:25 +0000 2017|@725616 Thanks for contacting us. We'd like to gather some info on what is happening with your device. Let's meet in DM. https://t.co/GDrqU22YpT                                                                                                                   |                 |2555305                |725616 Thanks contacting us Wed like gather info happening device Lets meet DM httpstcoGDrqU22YpT                                                                               |[Thanks, contacting, us, Wed, like, gather, info, happening, device, Lets, meet, DM, httpstcoGDrqU22YpT]                                                                                   |positive |
# +-----------------------+--------+------------+-------+------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# only showing top 10 rows

# %%
df_superstore = spark.read.format("delta").load("hdfs://localhost:9000/delta_superstore")

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

def parse_superstore(df):
    superstore_schema = StructType([
        StructField("Row ID", StringType(), True),
        StructField("Order ID", StringType(), True),
        StructField("Order Date", StringType(), True),
        StructField("Ship Date", StringType(), True),
        StructField("Ship Mode", StringType(), True),
        StructField("Customer ID", StringType(), True),
        StructField("Customer Name", StringType(), True),
        StructField("Segment", StringType(), True),
        StructField("Country", StringType(), True),
        StructField("City", StringType(), True),
        StructField("State", StringType(), True),
        StructField("Postal Code", StringType(), True),
        StructField("Region", StringType(), True),
        StructField("Product ID", StringType(), True),
        StructField("Category", StringType(), True),
        StructField("Sub-Category", StringType(), True),
        StructField("Product Name", StringType(), True),
        StructField("Sales", StringType(), True),
        StructField("Quantity", StringType(), True),
        StructField("Discount", StringType(), True),
        StructField("Profit", StringType(), True)
    ])
    
    parsed_superstore = df.select(
        col("timestamp_kafka"),
        from_json(col("message"), superstore_schema).alias("parsed_data")
    ).select(
        col("timestamp_kafka"),
        col("parsed_data.Row ID").cast(IntegerType()).alias("row_id"),
        col("parsed_data.Order ID").alias("order_id"),
        to_date(col("parsed_data.Order Date"), "M/d/yyyy").alias("order_date"),
        to_date(col("parsed_data.Ship Date"), "M/d/yyyy").alias("ship_date"),
        col("parsed_data.Ship Mode").alias("ship_mode"),
        col("parsed_data.Customer ID").alias("customer_id"),
        col("parsed_data.Customer Name").alias("customer_name"),
        col("parsed_data.Segment").alias("segment"),
        col("parsed_data.Country").alias("country"),
        col("parsed_data.City").alias("city"),
        col("parsed_data.State").alias("state"),
        col("parsed_data.Postal Code").cast(IntegerType()).alias("postal_code"),
        col("parsed_data.Region").alias("region"),
        col("parsed_data.Product ID").alias("product_id"),
        col("parsed_data.Category").alias("category"),
        col("parsed_data.Sub-Category").alias("sub_category"),
        col("parsed_data.Product Name").alias("product_name"),
        col("parsed_data.Sales").cast(DecimalType(10,2)).alias("sales"),
        col("parsed_data.Quantity").cast(IntegerType()).alias("quantity"),
        col("parsed_data.Discount").cast(DecimalType(5,4)).alias("discount"),
        col("parsed_data.Profit").cast(DecimalType(10,2)).alias("profit")
    )
    
    return parsed_superstore
df_parsed_superstore = parse_superstore(df_superstore)

# %%
all_null_rows = df_parsed_superstore.filter(
    col("row_id").isNull() & 
    col("order_id").isNull() & 
    col("customer_name").isNull()
)
all_null_rows.show(10, truncate=False)
print(f"Total null: {all_null_rows.count()}")
# Out:
# +-----------------------+------+--------+----------+---------+---------+-----------+-------------+-------+-------+----+-----+-----------+------+----------+--------+------------+------------+-----+--------+--------+------+
# |timestamp_kafka        |row_id|order_id|order_date|ship_date|ship_mode|customer_id|customer_name|segment|country|city|state|postal_code|region|product_id|category|sub_category|product_name|sales|quantity|discount|profit|
# +-----------------------+------+--------+----------+---------+---------+-----------+-------------+-------+-------+----+-----+-----------+------+----------+--------+------------+------------+-----+--------+--------+------+
# |2025-06-26 15:42:39.472|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.473|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.479|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.479|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.485|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.486|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.493|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.493|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.494|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# |2025-06-26 15:42:39.498|NULL  |NULL    |NULL      |NULL     |NULL     |NULL       |NULL         |NULL   |NULL   |NULL|NULL |NULL       |NULL  |NULL      |NULL    |NULL        |NULL        |NULL |NULL    |NULL    |NULL  |
# +-----------------------+------+--------+----------+---------+---------+-----------+-------------+-------+-------+----+-----+-----------+------+----------+--------+------------+------------+-----+--------+--------+------+
# only showing top 10 rows
# Total null: 268

# %%
df_parsed_superstore=df_parsed_superstore.dropna()
print(df_parsed_superstore.count())
# Out:
# 9668

# %%
spark.sql("USE db_tgp2")
spark.sql("DROP TABLE IF EXISTS dim_date")
spark.sql("CREATE TABLE dim_date (date_id INT, date INT, month INT, year INT) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_ship")
spark.sql("CREATE TABLE dim_ship (ship_id INT, ship_mode STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_city")
spark.sql("CREATE TABLE dim_city (city_id INT, city_name STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_customer")
spark.sql("CREATE TABLE dim_customer (customer_id INT, customer_name STRING, zipcode STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_state")
spark.sql("CREATE TABLE dim_state (state_id INT, state_name STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_segment")
spark.sql("CREATE TABLE dim_segment (segment_id INT, segment STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_region")
spark.sql("CREATE TABLE dim_region (region_id INT, region STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_product")
spark.sql("CREATE TABLE dim_product (product_id INT, product_name STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_product_category")
spark.sql("CREATE TABLE dim_product_category (category_id INT, product_category STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_product_subcategory")
spark.sql("CREATE TABLE dim_product_subcategory (subcategory_id INT, product_subcategory STRING) USING hive")

spark.sql("DROP TABLE IF EXISTS order_fact")
spark.sql("CREATE TABLE order_fact (order_id INT, sales DECIMAL(10,2), quantity INT, profits DECIMAL(10,2), discount DECIMAL(5,2)) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_product_hierarchy")
spark.sql("CREATE TABLE dim_product_hierarchy (product_id INT, category_id INT, subcategory_id INT) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_order")
spark.sql("CREATE TABLE dim_order (order_id INT, product_id INT, customer_id INT, ship_mode_id INT, order_date_id INT, shipment_date_id INT) USING hive")

spark.sql("DROP TABLE IF EXISTS dim_customer_location")
spark.sql("CREATE TABLE dim_customer_location (customer_id INT, city_id INT, state_id INT, segment_id INT, region_id INT) USING hive")
# Out:
# DataFrame[]

# %%
from pyspark.sql.window import Window
spark.sql("USE db_tgp2")
# Out:
# DataFrame[]

# %%
# dim_date
dates = df_parsed_superstore.select("order_date") \
    .union(df_parsed_superstore.select(col("ship_date").alias("order_date"))) \
    .distinct()

windowSpec = Window.orderBy("order_date")

dim_date = dates.withColumn("date_id", row_number().over(windowSpec)).select(
    col("date_id"),
    col("order_date").alias("date"),
    dayofmonth("order_date").alias("day"),
    month("order_date").alias("month"),
    year("order_date").alias("year")
)

dim_date.write.mode("overwrite").saveAsTable("dim_date")

spark.sql("SELECT * FROM dim_date").show()
# Out:
# +-------+----------+---+-----+----+
# |date_id|      date|day|month|year|
# +-------+----------+---+-----+----+
# |      1|2014-01-03|  3|    1|2014|
# |      2|2014-01-04|  4|    1|2014|
# |      3|2014-01-05|  5|    1|2014|
# |      4|2014-01-06|  6|    1|2014|
# |      5|2014-01-07|  7|    1|2014|
# |      6|2014-01-08|  8|    1|2014|
# |      7|2014-01-09|  9|    1|2014|
# |      8|2014-01-10| 10|    1|2014|
# |      9|2014-01-11| 11|    1|2014|
# |     10|2014-01-12| 12|    1|2014|
# |     11|2014-01-13| 13|    1|2014|
# |     12|2014-01-14| 14|    1|2014|
# |     13|2014-01-15| 15|    1|2014|
# |     14|2014-01-16| 16|    1|2014|
# |     15|2014-01-17| 17|    1|2014|
# |     16|2014-01-18| 18|    1|2014|
# |     17|2014-01-19| 19|    1|2014|
# |     18|2014-01-20| 20|    1|2014|
# |     19|2014-01-21| 21|    1|2014|
# |     20|2014-01-23| 23|    1|2014|
# +-------+----------+---+-----+----+
# only showing top 20 rows

# %%
# dim_ship
dim_ship = df_parsed_superstore.select("ship_mode").distinct()
windowSpec = Window.orderBy("ship_mode")
dim_ship = dim_ship.withColumn("ship_id", row_number().over(windowSpec)).select("ship_id", "ship_mode")
dim_ship.write.mode("overwrite").saveAsTable("dim_ship")

spark.sql("SELECT * FROM dim_ship").show()
# Out:
# +-------+--------------+
# |ship_id|     ship_mode|
# +-------+--------------+
# |      1|   First Class|
# |      2|      Same Day|
# |      3|  Second Class|
# |      4|Standard Class|
# +-------+--------------+

# %%
# dim_city
dim_city = df_parsed_superstore.select("city").distinct()
windowSpec = Window.orderBy("city")
dim_city = dim_city.withColumn("city_id", row_number().over(windowSpec)).select(
    col("city_id"), col("city").alias("city_name")
)
dim_city.write.mode("overwrite").saveAsTable("dim_city")
spark.sql("SELECT * FROM dim_city").show()
# Out:
# +-------+-----------------+
# |city_id|        city_name|
# +-------+-----------------+
# |      1|         Aberdeen|
# |      2|          Abilene|
# |      3|            Akron|
# |      4|      Albuquerque|
# |      5|       Alexandria|
# |      6|            Allen|
# |      7|        Allentown|
# |      8|          Altoona|
# |      9|         Amarillo|
# |     10|          Anaheim|
# |     11|          Andover|
# |     12|        Ann Arbor|
# |     13|          Antioch|
# |     14|           Apopka|
# |     15|     Apple Valley|
# |     16|         Appleton|
# |     17|        Arlington|
# |     18|Arlington Heights|
# |     19|           Arvada|
# |     20|        Asheville|
# +-------+-----------------+
# only showing top 20 rows

# %%
# dim_customer
dim_customer = df_parsed_superstore.select("customer_id", "customer_name").distinct()
windowSpec = Window.orderBy("customer_name")
dim_customer = dim_customer.withColumn("customer_id", row_number().over(windowSpec)).select(
    col("customer_id"), col("customer_name")
)
dim_customer.write.mode("overwrite").saveAsTable("dim_customer")
spark.sql("SELECT * FROM dim_customer").show()
# Out:
# +-----------+--------------------+
# |customer_id|       customer_name|
# +-----------+--------------------+
# |          1|       Aaron Bergman|
# |          2|       Aaron Hawkins|
# |          3|      Aaron Smayling|
# |          4|     Adam Bellavance|
# |          5|           Adam Hart|
# |          6|  Adam Shillingsburg|
# |          7|       Adrian Barton|
# |          8|         Adrian Hane|
# |          9|        Adrian Shami|
# |         10|         Aimee Bixby|
# |         11|         Alan Barnes|
# |         12|      Alan Dominguez|
# |         13|         Alan Haines|
# |         14|          Alan Hwang|
# |         15|   Alan Schoenberger|
# |         16|        Alan Shonely|
# |         17|Alejandro Ballentine|
# |         18|     Alejandro Grove|
# |         19|    Alejandro Savely|
# |         20| Aleksandra Gannaway|
# +-----------+--------------------+
# only showing top 20 rows

# %%
# dim_state
dim_state = df_parsed_superstore.select("state").distinct()
windowSpec = Window.orderBy("state")
dim_state = dim_state.withColumn("state_id", row_number().over(windowSpec)).select(
    col("state_id"), col("state").alias("state_name")
)
dim_state.write.mode("overwrite").saveAsTable("dim_state")
spark.sql("SELECT * FROM dim_state").show()
# Out:
# +--------+--------------------+
# |state_id|          state_name|
# +--------+--------------------+
# |       1|             Alabama|
# |       2|             Arizona|
# |       3|            Arkansas|
# |       4|          California|
# |       5|            Colorado|
# |       6|         Connecticut|
# |       7|            Delaware|
# |       8|District of Columbia|
# |       9|             Florida|
# |      10|             Georgia|
# |      11|               Idaho|
# |      12|            Illinois|
# |      13|             Indiana|
# |      14|                Iowa|
# |      15|              Kansas|
# |      16|            Kentucky|
# |      17|           Louisiana|
# |      18|               Maine|
# |      19|            Maryland|
# |      20|       Massachusetts|
# +--------+--------------------+
# only showing top 20 rows

# %%
# dim_segment
dim_segment = df_parsed_superstore.select("segment").distinct()
windowSpec = Window.orderBy("segment")
dim_segment = dim_segment.withColumn("segment_id", row_number().over(windowSpec)).select("segment_id", "segment")
dim_segment.write.mode("overwrite").saveAsTable("dim_segment")
spark.sql("SELECT * FROM dim_segment").show()
# Out:
# +----------+-----------+
# |segment_id|    segment|
# +----------+-----------+
# |         1|   Consumer|
# |         2|  Corporate|
# |         3|Home Office|
# +----------+-----------+

# %%
# dim_region
dim_region = df_parsed_superstore.select("region").distinct()
windowSpec = Window.orderBy("region")
dim_region = dim_region.withColumn("region_id", row_number().over(windowSpec)).select("region_id", "region")
dim_region.write.mode("overwrite").saveAsTable("dim_region")
spark.sql("SELECT * FROM dim_region").show()
# Out:
# +---------+-------+
# |region_id| region|
# +---------+-------+
# |        1|Central|
# |        2|   East|
# |        3|  South|
# |        4|   West|
# +---------+-------+

# %%
# dim_product
dim_product = df_parsed_superstore.select("product_id", "product_name").distinct()
windowSpec = Window.orderBy("product_name")
dim_product = dim_product.withColumn("product_id", row_number().over(windowSpec)).select("product_id", "product_name")
dim_product.write.mode("overwrite").saveAsTable("dim_product")
spark.sql("SELECT * FROM dim_product").show()
# Out:
# +----------+--------------------+
# |product_id|        product_name|
# +----------+--------------------+
# |         1|"While you Were O...|
# |         2|#10 Gummed Flap W...|
# |         3|#10 Self-Seal Whi...|
# |         4|#10 White Busines...|
# |         5|#10- 4 1/8" x 9 1...|
# |         6|#10- 4 1/8" x 9 1...|
# |         7|#10- 4 1/8" x 9 1...|
# |         8|#10-4 1/8" x 9 1/...|
# |         9|#6 3/4 Gummed Fla...|
# |        10|1.7 Cubic Foot Co...|
# |        11|1/4 Fold Party De...|
# |        12|12 Colored Short ...|
# |        13|12-1/2 Diameter R...|
# |        14|14-7/8 x 11 Blue ...|
# |        15|2300 Heavy-Duty T...|
# |        16|24 Capacity Maxi ...|
# |        17|24-Hour Round Wal...|
# |        18|  3-ring staple pack|
# |        19|3.6 Cubic Foot Co...|
# |        20|36X48 HARDFLOOR C...|
# +----------+--------------------+
# only showing top 20 rows

# %%
# dim_product_category
dim_product_category = df_parsed_superstore.select("category").distinct()
windowSpec = Window.orderBy("category")
dim_product_category = dim_product_category.withColumn("category_id", row_number().over(windowSpec)).select(
    col("category_id"), col("category").alias("product_category")
)
dim_product_category.write.mode("overwrite").saveAsTable("dim_product_category")
spark.sql("SELECT * FROM dim_product_category").show()
# Out:
# +-----------+----------------+
# |category_id|product_category|
# +-----------+----------------+
# |          1|       Furniture|
# |          2| Office Supplies|
# |          3|      Technology|
# +-----------+----------------+

# %%
# dim_product_subcategory
dim_product_subcategory = df_parsed_superstore.select("sub_category").distinct()
windowSpec = Window.orderBy("sub_category")
dim_product_subcategory = dim_product_subcategory.withColumn("subcategory_id", row_number().over(windowSpec)).select(
    col("subcategory_id"), col("sub_category").alias("product_subcategory")
)
dim_product_subcategory.write.mode("overwrite").saveAsTable("dim_product_subcategory")
spark.sql("SELECT * FROM dim_product_subcategory").show()
# Out:
# +--------------+-------------------+
# |subcategory_id|product_subcategory|
# +--------------+-------------------+
# |             1|        Accessories|
# |             2|         Appliances|
# |             3|                Art|
# |             4|            Binders|
# |             5|          Bookcases|
# |             6|             Chairs|
# |             7|            Copiers|
# |             8|          Envelopes|
# |             9|          Fasteners|
# |            10|        Furnishings|
# |            11|             Labels|
# |            12|           Machines|
# |            13|              Paper|
# |            14|             Phones|
# |            15|            Storage|
# |            16|           Supplies|
# |            17|             Tables|
# +--------------+-------------------+

# %%
# dim_product_hierarchy
product_hier = df_parsed_superstore.select("product_name", "category", "sub_category").distinct()

product_lookup = spark.sql("SELECT product_id, product_name FROM dim_product")
category_lookup = spark.sql("SELECT category_id, product_category FROM dim_product_category")
subcategory_lookup = spark.sql("SELECT subcategory_id, product_subcategory FROM dim_product_subcategory")

product_hierarchy = product_hier.join(
    product_lookup, product_hier.product_name == product_lookup.product_name, "inner"
).join(
    category_lookup, product_hier.category == category_lookup.product_category, "inner"
).join(
    subcategory_lookup, product_hier.sub_category == subcategory_lookup.product_subcategory, "inner"
).select(
    product_lookup.product_id,
    category_lookup.category_id,
    subcategory_lookup.subcategory_id
)

product_hierarchy.write.mode("overwrite").saveAsTable("dim_product_hierarchy")
spark.sql("SELECT * FROM dim_product_hierarchy").show()
# Out:
# +----------+-----------+--------------+
# |product_id|category_id|subcategory_id|
# +----------+-----------+--------------+
# |      1014|          2|            16|
# |      1430|          2|            13|
# |       590|          1|            10|
# |       187|          2|            11|
# |      1296|          2|             8|
# |       184|          2|            11|
# |      1303|          2|            13|
# |      1219|          2|             3|
# |      1241|          3|             1|
# |      1256|          2|            15|
# |       881|          1|            10|
# |       147|          3|            14|
# |        98|          2|            16|
# |      1397|          2|            11|
# |       989|          3|             1|
# |      1451|          2|            15|
# |         6|          2|             8|
# |         5|          2|             8|
# |       739|          1|             6|
# |       108|          2|            13|
# +----------+-----------+--------------+
# only showing top 20 rows

# %%
# dim_customer_location
cust_loc = df_parsed_superstore.select("customer_name", "city", "state", "segment", "region").distinct()

customer_lookup = spark.sql("SELECT customer_id, customer_name FROM dim_customer")
city_lookup = spark.sql("SELECT city_id, city_name FROM dim_city")
state_lookup = spark.sql("SELECT state_id, state_name FROM dim_state")
segment_lookup = spark.sql("SELECT segment_id, segment FROM dim_segment")
region_lookup = spark.sql("SELECT region_id, region FROM dim_region")

customer_location = cust_loc.join(
    customer_lookup, cust_loc.customer_name == customer_lookup.customer_name, "inner"
).join(
    city_lookup, cust_loc.city == city_lookup.city_name, "inner"
).join(
    state_lookup, cust_loc.state == state_lookup.state_name, "inner"
).join(
    segment_lookup, cust_loc.segment == segment_lookup.segment, "inner"
).join(
    region_lookup, cust_loc.region == region_lookup.region, "inner"
).select(
    customer_lookup.customer_id,
    city_lookup.city_id,
    state_lookup.state_id,
    segment_lookup.segment_id,
    region_lookup.region_id
)

customer_location.write.mode("overwrite").saveAsTable("dim_customer_location")
spark.sql("SELECT * FROM dim_customer_location").show()
# Out:
# +-----------+-------+--------+----------+---------+
# |customer_id|city_id|state_id|segment_id|region_id|
# +-----------+-------+--------+----------+---------+
# |        792|    428|      36|         1|        4|
# |        201|    449|      46|         3|        4|
# |        361|     61|      32|         1|        3|
# |        145|    374|      37|         1|        2|
# |        160|    374|      37|         1|        2|
# |        476|     84|      34|         1|        2|
# |        674|     81|      12|         3|        1|
# |        728|    148|      34|         1|        2|
# |        687|    217|       9|         3|        3|
# |        480|    330|      31|         1|        2|
# |        618|    208|      42|         1|        1|
# |        310|     81|      12|         1|        1|
# |        255|    406|      45|         2|        3|
# |        757|    518|       7|         2|        2|
# |        220|    395|       4|         1|        4|
# |        721|    438|       4|         1|        4|
# |        232|     73|       2|         2|        4|
# |        651|     17|      45|         1|        3|
# |        786|    322|      12|         1|        1|
# |        147|    267|       4|         1|        4|
# +-----------+-------+--------+----------+---------+
# only showing top 20 rows

# %%
# order_fact
order_fact = df_parsed_superstore.groupBy("order_id").agg(
    sum("sales").alias("sales"),
    sum("quantity").alias("quantity"), 
    sum("profit").alias("profits"),
    sum(col("sales") * col("discount")).alias("total_discount_amount")
).withColumn("id", row_number().over(Window.orderBy("order_id")))  # Surrogate key

order_fact = order_fact.select("id", "order_id", "sales", "quantity", "profits", "total_discount_amount")

order_fact.write.mode("overwrite").saveAsTable("order_fact")
spark.sql("SELECT * FROM order_fact").show()
# Out:
# +---+--------------+------+--------+-------+---------------------+
# | id|      order_id| sales|quantity|profits|total_discount_amount|
# +---+--------------+------+--------+-------+---------------------+
# |  1|CA-2014-100006|377.97|       3| 109.61|             0.000000|
# |  2|CA-2014-100090|699.19|       9| -19.09|           139.838000|
# |  3|CA-2014-100293| 91.06|       6|  31.87|            18.212000|
# |  4|CA-2014-100328|  3.93|       1|   1.33|             0.786000|
# |  5|CA-2014-100363| 21.38|       5|   7.72|             4.276000|
# |  6|CA-2014-100391| 14.62|       2|   6.73|             0.000000|
# |  7|CA-2014-100678|697.08|      11|  61.80|           171.122000|
# |  8|CA-2014-100706|129.44|       8|  17.72|             0.000000|
# |  9|CA-2014-100762|508.62|      11| 219.08|             0.000000|
# | 10|CA-2014-100860| 18.75|       5|   9.00|             0.000000|
# | 11|CA-2014-100867|321.55|       6|  20.10|            64.310000|
# | 12|CA-2014-100881|302.38|       3|  22.68|            60.476000|
# | 13|CA-2014-100895|605.47|       7| 176.92|             0.000000|
# | 14|CA-2014-100916|788.86|      10| 122.97|             0.000000|
# | 15|CA-2014-100972|166.44|       3|  79.89|             0.000000|
# | 16|CA-2014-101147|  2.39|       1|  -6.34|             1.912000|
# | 17|CA-2014-101175|100.70|       6|  -1.26|            20.140000|
# | 18|CA-2014-101266| 13.36|       2|   6.41|             0.000000|
# | 19|CA-2014-101364|296.71|      13| 100.14|            59.342000|
# | 20|CA-2014-101392|269.36|       7|  70.03|             0.000000|
# +---+--------------+------+--------+-------+---------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col, dayofmonth, month, year, row_number
from pyspark.sql.window import Window

base_order = df_parsed_superstore.select(
    "order_id", "product_name", "customer_name", "ship_mode", "order_date", "ship_date"
)

# Step 2: Ambil dimensi
order_fact = spark.sql("SELECT id AS dim_order_id, order_id FROM order_fact")
product = spark.sql("SELECT product_id, product_name FROM dim_product")
customer = spark.sql("SELECT customer_id, customer_name FROM dim_customer")
ship = spark.sql("SELECT ship_id, ship_mode FROM dim_ship")
date = spark.sql("SELECT date_id, date, day, month, year FROM dim_date")

dim_order = base_order \
    .join(order_fact, on="order_id", how="inner") \
    .join(product, on="product_name", how="inner") \
    .join(customer, on="customer_name", how="inner") \
    .join(ship, on="ship_mode", how="inner") \
    .join(
        date.alias("od"),
        col("order_date") == col("od.date"),
        "inner"
    ) \
    .join(
        date.alias("sd"),
        col("ship_date") == col("sd.date"),
        "inner"
    ) \
    .select(
        col("dim_order_id"),
        col("product_id").alias("dim_product_id"),
        col("customer_id").alias("dim_customer_id"),
        col("ship_id").alias("dim_ship_mode_id"),
        col("od.date_id").alias("dim_order_date_id"),
        col("sd.date_id").alias("dim_shipment_date_id")
    ).dropDuplicates()


# Step 4: Join semua
# dim_order = base_order \
#     .join(order_fact, on="order_id", how="inner") \
#     .join(product, on="product_name", how="inner") \
#     .join(ship, on="ship_mode", how="inner") \
#     .join(
#         date.alias("od"),
#         (dayofmonth("order_date") == col("od.day")) &
#         (month("order_date") == col("od.month")) &
#         (year("order_date") == col("od.year")),
#         "inner"
#     ) \
#     .join(
#         date.alias("sd"),
#         (dayofmonth("ship_date") == col("sd.date")) &
#         (month("ship_date") == col("sd.month")) &
#         (year("ship_date") == col("sd.year")),
#         "inner"
#     ) \
#     .select(
#         col("dim_order_id"),
#         col("product_id").alias("dim_product_id"),
#         col("customer_id").alias("dim_customer_id"),
#         col("ship_id").alias("dim_ship_mode_id"),
#         col("od.date_id").alias("dim_order_date_id"),
#         col("sd.date_id").alias("dim_shipment_date_id")
#     ).dropDuplicates()

# Step 5: Simpan ke Hive
dim_order.write.mode("overwrite").saveAsTable("dim_order")
# Cek hasilnya
spark.sql("SELECT * FROM dim_order ORDER BY dim_order_id").show()
# Out:
# +------------+--------------+---------------+----------------+-----------------+--------------------+
# |dim_order_id|dim_product_id|dim_customer_id|dim_ship_mode_id|dim_order_date_id|dim_shipment_date_id|
# +------------+--------------+---------------+----------------+-----------------+--------------------+
# |           1|            46|            224|               4|              237|                 243|
# |           2|          1628|            246|               4|              178|                 182|
# |           2|           826|            246|               4|              178|                 182|
# |           3|          1657|            564|               4|               66|                  70|
# |           4|          1268|            355|               4|               24|                  30|
# |           5|          1557|            376|               4|               90|                  96|
# |           5|           327|            376|               4|               90|                  96|
# |           6|          1506|             71|               4|              136|                 140|
# |           7|           392|            447|               4|               99|                 103|
# |           7|          1261|            447|               4|               99|                 103|
# |           7|           490|            447|               4|               99|                 103|
# |           7|           938|            447|               4|               99|                 103|
# |           8|           417|            453|               3|              337|                 339|
# |           8|          1577|            453|               3|              337|                 339|
# |           9|           888|            556|               4|              315|                 320|
# |           9|           527|            556|               4|              315|                 320|
# |           9|          1655|            556|               4|              315|                 320|
# |           9|           109|            556|               4|              315|                 320|
# |          10|          1416|            166|               3|               78|                  81|
# |          11|          1286|            274|               4|              279|                 284|
# +------------+--------------+---------------+----------------+-----------------+--------------------+
# only showing top 20 rows
